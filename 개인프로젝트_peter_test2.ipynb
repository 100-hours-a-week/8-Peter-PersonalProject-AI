# %%
# Kaggle API 키 설정
import os
os.environ["KAGGLE_CONFIG_DIR"] = "/content"

# Kaggle 데이터 다운로드
# !kaggle datasets download -d jonathansilva2020/orange-diseases-dataset
# !unzip /content/orange-diseases-dataset.zip -d /content/orange-diseases-dataset
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.7.4.2 / client 1.6.17)
# Dataset URL: https://www.kaggle.com/datasets/jonathansilva2020/orange-diseases-dataset
# License(s): CC-BY-NC-SA-4.0
# Downloading orange-diseases-dataset.zip to /content
#  90% 124M/138M [00:01<00:00, 127MB/s]
# 100% 138M/138M [00:01<00:00, 123MB/s]
# Archive:  /content/orange-diseases-dataset.zip
#   inflating: /content/orange-diseases-dataset/test/blackspot/b (1).jpg
#   inflating: /content/orange-diseases-dataset/test/blackspot/b (10).jpg
#   inflating: /content/orange-diseases-dataset/test/blackspot/b (11).jpg
#   inflating: /content/orange-diseases-dataset/test/blackspot/b (12).jpg
#   inflating: /content/orange-diseases-dataset/test/blackspot/b (13).jpg
#   inflating: /content/orange-diseases-dataset/test/blackspot/b (14).jpg
#   inflating: /content/orange-diseases-dataset/test/blackspot/b (15).jpg
#   inflating: /content/orange-diseases-dataset/test/blackspot/b (16).jpg
#   inflating: /content/orange-diseases-dataset/test/blackspot/b (17).jpg
#   inflating: /content/orange-diseases-dataset/test/blackspot/b (18).jpg
#   inflating: /content/orange-diseases-dataset/test/blackspot/b (19).jpg
#   inflating: /content/orange-diseases-dataset/test/blackspot/b (2).jpg
#   inflating: /content/orange-diseases-dataset/test/blackspot/b (20).jpg
#   inflating: /content/orange-diseases-dataset/test/blackspot/b (21).jpg
#   inflating: /content/orange-diseases-dataset/test/blackspot/b (22).jpg
#   inflating: /content/orange-diseases-dataset/test/blackspot/b (3).jpg
#   inflating: /content/orange-diseases-dataset/test/blackspot/b (4).jpg
#   inflating: /content/orange-diseases-dataset/test/blackspot/b (5).jpg
#   inflating: /content/orange-diseases-dataset/test/blackspot/b (6).jpg
#   inflating: /content/orange-diseases-dataset/test/blackspot/b (7).jpg
#   inflating: /content/orange-diseases-dataset/test/blackspot/b (8).jpg
#   inflating: /content/orange-diseases-dataset/test/blackspot/b (9).jpg
#   inflating: /content/orange-diseases-dataset/test/canker/c (1).jpg
#   inflating: /content/orange-diseases-dataset/test/canker/c (10).jpg
#   inflating: /content/orange-diseases-dataset/test/canker/c (11).jpg
#   inflating: /content/orange-diseases-dataset/test/canker/c (12).jpg
#   inflating: /content/orange-diseases-dataset/test/canker/c (13).jpg
#   inflating: /content/orange-diseases-dataset/test/canker/c (14).jpg
#   inflating: /content/orange-diseases-dataset/test/canker/c (15).jpg
#   inflating: /content/orange-diseases-dataset/test/canker/c (16).jpg
#   inflating: /content/orange-diseases-dataset/test/canker/c (17).jpg
#   inflating: /content/orange-diseases-dataset/test/canker/c (18).jpg
#   inflating: /content/orange-diseases-dataset/test/canker/c (19).jpg
#   inflating: /content/orange-diseases-dataset/test/canker/c (2).jpg
#   inflating: /content/orange-diseases-dataset/test/canker/c (20).jpg
#   inflating: /content/orange-diseases-dataset/test/canker/c (21).jpg
#   inflating: /content/orange-diseases-dataset/test/canker/c (22).jpg
#   inflating: /content/orange-diseases-dataset/test/canker/c (3).jpg
#   inflating: /content/orange-diseases-dataset/test/canker/c (4).jpg
#   inflating: /content/orange-diseases-dataset/test/canker/c (5).jpg
#   inflating: /content/orange-diseases-dataset/test/canker/c (6).jpg
#   inflating: /content/orange-diseases-dataset/test/canker/c (7).jpg
#   inflating: /content/orange-diseases-dataset/test/canker/c (8).jpg
#   inflating: /content/orange-diseases-dataset/test/canker/c (9).jpg
#   inflating: /content/orange-diseases-dataset/test/fresh/f (1).png
#   inflating: /content/orange-diseases-dataset/test/fresh/f (10).png
#   inflating: /content/orange-diseases-dataset/test/fresh/f (11).png
#   inflating: /content/orange-diseases-dataset/test/fresh/f (12).png
#   inflating: /content/orange-diseases-dataset/test/fresh/f (13).png
#   inflating: /content/orange-diseases-dataset/test/fresh/f (14).png
#   inflating: /content/orange-diseases-dataset/test/fresh/f (15).png
#   inflating: /content/orange-diseases-dataset/test/fresh/f (16).png
#   inflating: /content/orange-diseases-dataset/test/fresh/f (17).png
#   inflating: /content/orange-diseases-dataset/test/fresh/f (18).png
#   inflating: /content/orange-diseases-dataset/test/fresh/f (19).png
#   inflating: /content/orange-diseases-dataset/test/fresh/f (2).png
#   inflating: /content/orange-diseases-dataset/test/fresh/f (20).png
#   inflating: /content/orange-diseases-dataset/test/fresh/f (21).png
#   inflating: /content/orange-diseases-dataset/test/fresh/f (22).png
#   inflating: /content/orange-diseases-dataset/test/fresh/f (23).png
#   inflating: /content/orange-diseases-dataset/test/fresh/f (24).png
#   inflating: /content/orange-diseases-dataset/test/fresh/f (25).png
#   inflating: /content/orange-diseases-dataset/test/fresh/f (26).png
#   inflating: /content/orange-diseases-dataset/test/fresh/f (27).png
#   inflating: /content/orange-diseases-dataset/test/fresh/f (28).png
#   inflating: /content/orange-diseases-dataset/test/fresh/f (29).png
#   inflating: /content/orange-diseases-dataset/test/fresh/f (3).png
#   inflating: /content/orange-diseases-dataset/test/fresh/f (30).png
#   inflating: /content/orange-diseases-dataset/test/fresh/f (31).png
#   inflating: /content/orange-diseases-dataset/test/fresh/f (32).png
#   inflating: /content/orange-diseases-dataset/test/fresh/f (33).png
#   inflating: /content/orange-diseases-dataset/test/fresh/f (4).png
#   inflating: /content/orange-diseases-dataset/test/fresh/f (5).png
#   inflating: /content/orange-diseases-dataset/test/fresh/f (6).png
#   inflating: /content/orange-diseases-dataset/test/fresh/f (7).png
#   inflating: /content/orange-diseases-dataset/test/fresh/f (8).png
#   inflating: /content/orange-diseases-dataset/test/fresh/f (9).png
#   inflating: /content/orange-diseases-dataset/test/grenning/g (1).jpg
#   inflating: /content/orange-diseases-dataset/test/grenning/g (10).jpg
#   inflating: /content/orange-diseases-dataset/test/grenning/g (11).jpg
#   inflating: /content/orange-diseases-dataset/test/grenning/g (12).jpg
#   inflating: /content/orange-diseases-dataset/test/grenning/g (13).jpg
#   inflating: /content/orange-diseases-dataset/test/grenning/g (14).jpg
#   inflating: /content/orange-diseases-dataset/test/grenning/g (15).jpg
#   inflating: /content/orange-diseases-dataset/test/grenning/g (16).jpg
#   inflating: /content/orange-diseases-dataset/test/grenning/g (17).jpg
#   inflating: /content/orange-diseases-dataset/test/grenning/g (18).jpg
#   inflating: /content/orange-diseases-dataset/test/grenning/g (19).jpg
#   inflating: /content/orange-diseases-dataset/test/grenning/g (2).jpg
#   inflating: /content/orange-diseases-dataset/test/grenning/g (20).jpg
#   inflating: /content/orange-diseases-dataset/test/grenning/g (21).jpg
#   inflating: /content/orange-diseases-dataset/test/grenning/g (22).jpg
#   inflating: /content/orange-diseases-dataset/test/grenning/g (3).jpg
#   inflating: /content/orange-diseases-dataset/test/grenning/g (4).jpg
#   inflating: /content/orange-diseases-dataset/test/grenning/g (5).jpg
#   inflating: /content/orange-diseases-dataset/test/grenning/g (6).jpg
#   inflating: /content/orange-diseases-dataset/test/grenning/g (7).jpg
#   inflating: /content/orange-diseases-dataset/test/grenning/g (8).jpg
#   inflating: /content/orange-diseases-dataset/test/grenning/g (9).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (1).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (10).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (100).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (101).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (102).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (103).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (104).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (105).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (106).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (107).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (108).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (109).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (11).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (110).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (111).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (112).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (113).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (114).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (115).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (116).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (117).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (118).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (119).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (12).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (120).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (121).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (122).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (123).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (124).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (125).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (126).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (127).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (128).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (129).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (13).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (130).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (131).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (132).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (133).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (134).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (135).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (136).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (137).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (138).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (139).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (14).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (140).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (141).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (142).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (143).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (144).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (145).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (146).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (147).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (148).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (149).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (15).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (150).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (151).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (152).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (153).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (154).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (155).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (156).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (157).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (158).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (159).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (16).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (160).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (161).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (162).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (163).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (164).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (165).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (166).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (167).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (168).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (169).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (17).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (170).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (171).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (172).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (173).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (174).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (175).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (176).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (177).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (178).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (179).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (18).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (180).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (181).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (182).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (183).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (184).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (19).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (2).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (20).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (21).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (22).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (23).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (24).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (25).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (26).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (27).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (28).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (29).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (3).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (30).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (31).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (32).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (33).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (34).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (35).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (36).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (37).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (38).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (39).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (4).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (40).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (41).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (42).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (43).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (44).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (45).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (46).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (47).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (48).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (49).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (5).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (50).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (51).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (52).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (53).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (54).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (55).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (56).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (57).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (58).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (59).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (6).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (60).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (61).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (62).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (63).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (64).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (65).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (66).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (67).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (68).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (69).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (7).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (70).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (71).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (72).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (73).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (74).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (75).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (76).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (77).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (78).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (79).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (8).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (80).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (81).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (82).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (83).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (84).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (85).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (86).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (87).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (88).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (89).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (9).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (90).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (91).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (92).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (93).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (94).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (95).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (96).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (97).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (98).jpg
#   inflating: /content/orange-diseases-dataset/train/blackspot/b (99).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (1).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (10).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (100).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (101).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (102).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (103).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (104).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (105).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (106).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (107).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (108).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (109).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (11).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (110).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (111).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (112).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (113).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (114).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (115).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (116).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (117).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (118).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (119).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (12).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (120).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (121).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (122).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (123).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (124).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (125).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (126).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (127).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (128).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (129).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (13).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (130).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (131).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (132).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (133).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (134).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (135).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (136).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (137).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (138).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (139).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (14).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (140).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (141).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (142).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (143).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (144).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (145).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (146).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (147).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (148).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (149).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (15).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (150).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (151).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (152).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (153).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (154).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (155).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (156).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (157).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (158).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (159).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (16).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (160).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (161).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (162).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (163).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (164).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (165).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (166).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (167).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (168).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (169).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (17).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (170).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (171).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (172).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (173).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (174).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (175).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (176).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (177).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (178).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (179).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (18).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (19).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (2).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (20).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (21).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (22).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (23).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (24).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (25).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (26).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (27).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (28).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (29).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (3).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (30).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (31).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (32).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (33).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (34).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (35).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (36).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (37).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (38).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (39).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (4).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (40).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (41).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (42).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (43).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (44).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (45).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (46).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (47).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (48).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (49).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (5).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (50).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (51).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (52).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (53).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (54).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (55).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (56).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (57).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (58).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (59).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (6).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (60).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (61).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (62).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (63).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (64).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (65).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (66).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (67).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (68).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (69).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (7).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (70).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (71).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (72).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (73).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (74).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (75).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (76).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (77).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (78).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (79).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (8).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (80).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (81).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (82).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (83).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (84).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (85).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (86).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (87).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (88).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (89).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (9).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (90).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (91).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (92).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (93).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (94).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (95).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (96).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (97).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (98).jpg
#   inflating: /content/orange-diseases-dataset/train/canker/c (99).jpg
#   inflating: /content/orange-diseases-dataset/train/fresh/f (1).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (10).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (100).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (101).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (102).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (103).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (104).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (105).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (106).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (107).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (108).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (109).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (11).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (110).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (111).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (112).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (113).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (114).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (115).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (116).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (117).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (118).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (119).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (12).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (120).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (121).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (122).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (123).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (124).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (125).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (126).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (127).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (128).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (129).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (13).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (130).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (131).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (132).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (133).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (134).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (135).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (136).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (137).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (138).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (139).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (14).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (140).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (141).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (142).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (143).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (144).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (145).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (146).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (147).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (148).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (149).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (15).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (150).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (151).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (152).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (153).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (154).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (155).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (156).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (157).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (158).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (159).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (16).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (160).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (161).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (162).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (163).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (164).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (165).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (166).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (167).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (168).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (169).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (17).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (170).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (171).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (172).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (173).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (174).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (175).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (176).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (177).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (178).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (179).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (18).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (180).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (181).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (182).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (183).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (184).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (185).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (186).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (187).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (188).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (189).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (19).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (190).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (191).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (192).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (193).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (194).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (195).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (196).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (197).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (198).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (199).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (2).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (20).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (200).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (201).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (202).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (203).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (204).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (205).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (206).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (207).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (208).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (209).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (21).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (210).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (211).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (212).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (213).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (214).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (215).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (216).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (217).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (218).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (219).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (22).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (220).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (221).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (222).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (223).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (224).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (225).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (226).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (227).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (228).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (229).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (23).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (230).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (231).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (232).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (233).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (234).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (235).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (236).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (237).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (238).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (239).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (24).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (240).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (241).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (242).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (243).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (244).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (245).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (246).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (247).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (248).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (249).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (25).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (250).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (251).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (252).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (253).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (254).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (255).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (256).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (257).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (258).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (259).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (26).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (260).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (261).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (262).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (263).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (264).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (265).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (266).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (267).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (268).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (269).png
#   inflating: /content/orange-diseases-dataset/train/fresh/f (27).png
# ...
#   inflating: /content/orange-diseases-dataset/train/grenning/g (219).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (22).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (220).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (221).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (222).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (223).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (224).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (225).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (226).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (227).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (228).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (229).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (23).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (230).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (231).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (232).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (233).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (234).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (235).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (236).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (237).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (238).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (239).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (24).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (240).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (241).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (242).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (243).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (244).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (245).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (246).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (247).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (248).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (249).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (25).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (250).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (251).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (252).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (253).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (254).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (255).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (256).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (257).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (258).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (259).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (26).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (260).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (261).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (262).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (263).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (264).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (265).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (266).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (267).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (268).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (269).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (27).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (270).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (271).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (272).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (273).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (274).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (275).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (276).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (277).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (278).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (279).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (28).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (280).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (281).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (282).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (283).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (284).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (285).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (286).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (287).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (288).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (289).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (29).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (290).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (291).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (292).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (293).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (294).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (295).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (296).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (297).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (298).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (299).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (3).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (30).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (300).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (301).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (302).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (303).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (304).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (305).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (306).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (307).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (308).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (309).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (31).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (310).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (311).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (312).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (313).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (314).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (315).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (316).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (317).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (318).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (319).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (32).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (320).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (321).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (322).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (323).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (324).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (325).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (326).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (327).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (328).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (329).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (33).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (330).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (331).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (332).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (333).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (334).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (335).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (336).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (337).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (338).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (339).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (34).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (340).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (341).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (342).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (343).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (344).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (345).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (346).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (347).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (35).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (36).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (37).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (38).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (39).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (4).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (40).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (41).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (42).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (43).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (44).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (45).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (46).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (47).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (48).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (49).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (5).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (50).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (51).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (52).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (53).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (54).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (55).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (56).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (57).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (58).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (59).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (6).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (60).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (61).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (62).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (63).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (64).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (65).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (66).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (67).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (68).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (69).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (7).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (70).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (71).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (72).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (73).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (74).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (75).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (76).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (77).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (78).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (79).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (8).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (80).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (81).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (82).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (83).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (84).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (85).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (86).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (87).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (88).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (89).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (9).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (90).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (91).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (92).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (93).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (94).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (95).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (96).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (97).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (98).jpg
#   inflating: /content/orange-diseases-dataset/train/grenning/g (99).jpg

# %%
import os
import shutil
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# 데이터 경로 설정
data_dir = "/content/orange-diseases-dataset"
train_dir = os.path.join(data_dir, "train")
val_dir = os.path.join(data_dir, "val")

# 클래스 확인
classes = os.listdir(train_dir)
print("클래스 목록:", classes)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-0930a7f8564f> in <cell line: 0>()
#      11
#      12 # 클래스 확인
# ---> 13 classes = os.listdir(train_dir)
#      14 print("클래스 목록:", classes)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/orange-diseases-dataset/train'

# %% [markdown]
# 고급 데이터 증강(Augmentation) 적용
#  / 기본 변형: 회전, 이동, 반전, 확대 /
# 추가 변형: 밝기 조절, 대비 조정, 노이즈 추가

# %%
# 이미지 크기 및 배치 설정
IMG_SIZE = (256, 256)
BATCH_SIZE = 32

# 강력한 데이터 증강 적용
train_datagen = ImageDataGenerator(
    rescale=1.0 / 255.0,
    rotation_range=45,  # 회전 범위 증가
    width_shift_range=0.2,  # 가로 이동
    height_shift_range=0.2,  # 세로 이동
    horizontal_flip=True,  # 좌우 반전
    brightness_range=[0.5, 1.5],  # 밝기 조절
    zoom_range=0.3,  # 줌 조정
    shear_range=0.2,  # 기울이기 적용
    channel_shift_range=50.0  # 채널 색상 변형
)

val_datagen = ImageDataGenerator(rescale=1.0 / 255.0)

# 데이터 로딩
train_data = train_datagen.flow_from_directory(
    train_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode="categorical"
)

val_data = val_datagen.flow_from_directory(
    val_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode="categorical"
)
# Out:
# Found 991 images belonging to 4 classes.
# Found 99 images belonging to 4 classes.

# %% [markdown]
# Pretrained 모델(EfficientNetV2S) 사용
# 전이 학습 후 일부 레이어를 Fine-Tuning
# Dropout 적용하여 과적합 방지

# %%
from tensorflow.keras.applications import EfficientNetV2S
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout

# EfficientNetV2 모델 불러오기 (Pretrained weights 사용)
base_model = EfficientNetV2S(weights="imagenet", include_top=False, input_shape=(256, 256, 3))

# 기존 가중치 동결
base_model.trainable = False

# 분류기 추가
x = GlobalAveragePooling2D()(base_model.output)
x = Dense(512, activation="relu")(x)  # 더 큰 히든 레이어 추가
x = Dropout(0.4)(x)  # Dropout 증가
x = Dense(256, activation="relu")(x)
x = Dropout(0.3)(x)
x = Dense(len(classes), activation="softmax")(x)  # 클래스 개수만큼 출력 노드 설정

# 모델 생성
model = Model(inputs=base_model.input, outputs=x)

# 모델 컴파일 (적응형 학습률 사용)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# 모델 요약 출력
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-s_notop.h5
# 82420632/82420632 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 256, 256, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rescaling (Rescaling)     │ (None, 256, 256, 3)    │              0 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_conv (Conv2D)        │ (None, 128, 128, 24)   │            648 │ rescaling[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_bn                   │ (None, 128, 128, 24)   │             96 │ stem_conv[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_activation           │ (None, 128, 128, 24)   │              0 │ stem_bn[0][0]          │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_project_conv      │ (None, 128, 128, 24)   │          5,184 │ stem_activation[0][0]  │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_project_bn        │ (None, 128, 128, 24)   │             96 │ block1a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_project_activati… │ (None, 128, 128, 24)   │              0 │ block1a_project_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_add (Add)         │ (None, 128, 128, 24)   │              0 │ block1a_project_activ… │
# │                           │                        │                │ stem_activation[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_project_conv      │ (None, 128, 128, 24)   │          5,184 │ block1a_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_project_bn        │ (None, 128, 128, 24)   │             96 │ block1b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_project_activati… │ (None, 128, 128, 24)   │              0 │ block1b_project_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_drop (Dropout)    │ (None, 128, 128, 24)   │              0 │ block1b_project_activ… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_add (Add)         │ (None, 128, 128, 24)   │              0 │ block1b_drop[0][0],    │
# │                           │                        │                │ block1a_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_expand_conv       │ (None, 64, 64, 96)     │         20,736 │ block1b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_expand_bn         │ (None, 64, 64, 96)     │            384 │ block2a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_expand_activation │ (None, 64, 64, 96)     │              0 │ block2a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_project_conv      │ (None, 64, 64, 48)     │          4,608 │ block2a_expand_activa… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_project_bn        │ (None, 64, 64, 48)     │            192 │ block2a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_expand_conv       │ (None, 64, 64, 192)    │         82,944 │ block2a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_expand_bn         │ (None, 64, 64, 192)    │            768 │ block2b_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_expand_activation │ (None, 64, 64, 192)    │              0 │ block2b_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_project_conv      │ (None, 64, 64, 48)     │          9,216 │ block2b_expand_activa… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_project_bn        │ (None, 64, 64, 48)     │            192 │ block2b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_drop (Dropout)    │ (None, 64, 64, 48)     │              0 │ block2b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_add (Add)         │ (None, 64, 64, 48)     │              0 │ block2b_drop[0][0],    │
# │                           │                        │                │ block2a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_expand_conv       │ (None, 64, 64, 192)    │         82,944 │ block2b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_expand_bn         │ (None, 64, 64, 192)    │            768 │ block2c_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_expand_activation │ (None, 64, 64, 192)    │              0 │ block2c_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_project_conv      │ (None, 64, 64, 48)     │          9,216 │ block2c_expand_activa… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_project_bn        │ (None, 64, 64, 48)     │            192 │ block2c_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_drop (Dropout)    │ (None, 64, 64, 48)     │              0 │ block2c_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_add (Add)         │ (None, 64, 64, 48)     │              0 │ block2c_drop[0][0],    │
# │                           │                        │                │ block2b_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_expand_conv       │ (None, 64, 64, 192)    │         82,944 │ block2c_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_expand_bn         │ (None, 64, 64, 192)    │            768 │ block2d_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_expand_activation │ (None, 64, 64, 192)    │              0 │ block2d_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_project_conv      │ (None, 64, 64, 48)     │          9,216 │ block2d_expand_activa… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_project_bn        │ (None, 64, 64, 48)     │            192 │ block2d_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_drop (Dropout)    │ (None, 64, 64, 48)     │              0 │ block2d_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_add (Add)         │ (None, 64, 64, 48)     │              0 │ block2d_drop[0][0],    │
# │                           │                        │                │ block2c_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_expand_conv       │ (None, 32, 32, 192)    │         82,944 │ block2d_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_expand_bn         │ (None, 32, 32, 192)    │            768 │ block3a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_expand_activation │ (None, 32, 32, 192)    │              0 │ block3a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_project_conv      │ (None, 32, 32, 64)     │         12,288 │ block3a_expand_activa… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_project_bn        │ (None, 32, 32, 64)     │            256 │ block3a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_expand_conv       │ (None, 32, 32, 256)    │        147,456 │ block3a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_expand_bn         │ (None, 32, 32, 256)    │          1,024 │ block3b_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_expand_activation │ (None, 32, 32, 256)    │              0 │ block3b_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_project_conv      │ (None, 32, 32, 64)     │         16,384 │ block3b_expand_activa… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_project_bn        │ (None, 32, 32, 64)     │            256 │ block3b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_drop (Dropout)    │ (None, 32, 32, 64)     │              0 │ block3b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_add (Add)         │ (None, 32, 32, 64)     │              0 │ block3b_drop[0][0],    │
# │                           │                        │                │ block3a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_expand_conv       │ (None, 32, 32, 256)    │        147,456 │ block3b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_expand_bn         │ (None, 32, 32, 256)    │          1,024 │ block3c_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_expand_activation │ (None, 32, 32, 256)    │              0 │ block3c_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_project_conv      │ (None, 32, 32, 64)     │         16,384 │ block3c_expand_activa… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_project_bn        │ (None, 32, 32, 64)     │            256 │ block3c_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_drop (Dropout)    │ (None, 32, 32, 64)     │              0 │ block3c_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_add (Add)         │ (None, 32, 32, 64)     │              0 │ block3c_drop[0][0],    │
# │                           │                        │                │ block3b_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_expand_conv       │ (None, 32, 32, 256)    │        147,456 │ block3c_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_expand_bn         │ (None, 32, 32, 256)    │          1,024 │ block3d_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_expand_activation │ (None, 32, 32, 256)    │              0 │ block3d_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_project_conv      │ (None, 32, 32, 64)     │         16,384 │ block3d_expand_activa… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_project_bn        │ (None, 32, 32, 64)     │            256 │ block3d_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_drop (Dropout)    │ (None, 32, 32, 64)     │              0 │ block3d_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_add (Add)         │ (None, 32, 32, 64)     │              0 │ block3d_drop[0][0],    │
# │                           │                        │                │ block3c_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_expand_conv       │ (None, 32, 32, 256)    │         16,384 │ block3d_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_expand_bn         │ (None, 32, 32, 256)    │          1,024 │ block4a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_expand_activation │ (None, 32, 32, 256)    │              0 │ block4a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_dwconv2           │ (None, 16, 16, 256)    │          2,304 │ block4a_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_bn                │ (None, 16, 16, 256)    │          1,024 │ block4a_dwconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_activation        │ (None, 16, 16, 256)    │              0 │ block4a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_squeeze        │ (None, 256)            │              0 │ block4a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_reshape        │ (None, 1, 1, 256)      │              0 │ block4a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_reduce         │ (None, 1, 1, 16)       │          4,112 │ block4a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_expand         │ (None, 1, 1, 256)      │          4,352 │ block4a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_excite         │ (None, 16, 16, 256)    │              0 │ block4a_activation[0]… │
# │ (Multiply)                │                        │                │ block4a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_project_conv      │ (None, 16, 16, 128)    │         32,768 │ block4a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_project_bn        │ (None, 16, 16, 128)    │            512 │ block4a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_expand_conv       │ (None, 16, 16, 512)    │         65,536 │ block4a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_expand_bn         │ (None, 16, 16, 512)    │          2,048 │ block4b_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_expand_activation │ (None, 16, 16, 512)    │              0 │ block4b_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_dwconv2           │ (None, 16, 16, 512)    │          4,608 │ block4b_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_bn                │ (None, 16, 16, 512)    │          2,048 │ block4b_dwconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_activation        │ (None, 16, 16, 512)    │              0 │ block4b_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_squeeze        │ (None, 512)            │              0 │ block4b_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_reshape        │ (None, 1, 1, 512)      │              0 │ block4b_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_reduce         │ (None, 1, 1, 32)       │         16,416 │ block4b_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_expand         │ (None, 1, 1, 512)      │         16,896 │ block4b_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_excite         │ (None, 16, 16, 512)    │              0 │ block4b_activation[0]… │
# │ (Multiply)                │                        │                │ block4b_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_project_conv      │ (None, 16, 16, 128)    │         65,536 │ block4b_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_project_bn        │ (None, 16, 16, 128)    │            512 │ block4b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_drop (Dropout)    │ (None, 16, 16, 128)    │              0 │ block4b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_add (Add)         │ (None, 16, 16, 128)    │              0 │ block4b_drop[0][0],    │
# │                           │                        │                │ block4a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_expand_conv       │ (None, 16, 16, 512)    │         65,536 │ block4b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_expand_bn         │ (None, 16, 16, 512)    │          2,048 │ block4c_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_expand_activation │ (None, 16, 16, 512)    │              0 │ block4c_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_dwconv2           │ (None, 16, 16, 512)    │          4,608 │ block4c_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_bn                │ (None, 16, 16, 512)    │          2,048 │ block4c_dwconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_activation        │ (None, 16, 16, 512)    │              0 │ block4c_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_squeeze        │ (None, 512)            │              0 │ block4c_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_reshape        │ (None, 1, 1, 512)      │              0 │ block4c_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_reduce         │ (None, 1, 1, 32)       │         16,416 │ block4c_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_expand         │ (None, 1, 1, 512)      │         16,896 │ block4c_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_excite         │ (None, 16, 16, 512)    │              0 │ block4c_activation[0]… │
# │ (Multiply)                │                        │                │ block4c_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_project_conv      │ (None, 16, 16, 128)    │         65,536 │ block4c_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_project_bn        │ (None, 16, 16, 128)    │            512 │ block4c_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_drop (Dropout)    │ (None, 16, 16, 128)    │              0 │ block4c_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_add (Add)         │ (None, 16, 16, 128)    │              0 │ block4c_drop[0][0],    │
# │                           │                        │                │ block4b_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_expand_conv       │ (None, 16, 16, 512)    │         65,536 │ block4c_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_expand_bn         │ (None, 16, 16, 512)    │          2,048 │ block4d_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_expand_activation │ (None, 16, 16, 512)    │              0 │ block4d_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_dwconv2           │ (None, 16, 16, 512)    │          4,608 │ block4d_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_bn                │ (None, 16, 16, 512)    │          2,048 │ block4d_dwconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_activation        │ (None, 16, 16, 512)    │              0 │ block4d_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_se_squeeze        │ (None, 512)            │              0 │ block4d_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_se_reshape        │ (None, 1, 1, 512)      │              0 │ block4d_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_se_reduce         │ (None, 1, 1, 32)       │         16,416 │ block4d_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_se_expand         │ (None, 1, 1, 512)      │         16,896 │ block4d_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_se_excite         │ (None, 16, 16, 512)    │              0 │ block4d_activation[0]… │
# │ (Multiply)                │                        │                │ block4d_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_project_conv      │ (None, 16, 16, 128)    │         65,536 │ block4d_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_project_bn        │ (None, 16, 16, 128)    │            512 │ block4d_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_drop (Dropout)    │ (None, 16, 16, 128)    │              0 │ block4d_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_add (Add)         │ (None, 16, 16, 128)    │              0 │ block4d_drop[0][0],    │
# │                           │                        │                │ block4c_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_expand_conv       │ (None, 16, 16, 512)    │         65,536 │ block4d_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_expand_bn         │ (None, 16, 16, 512)    │          2,048 │ block4e_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_expand_activation │ (None, 16, 16, 512)    │              0 │ block4e_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_dwconv2           │ (None, 16, 16, 512)    │          4,608 │ block4e_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_bn                │ (None, 16, 16, 512)    │          2,048 │ block4e_dwconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_activation        │ (None, 16, 16, 512)    │              0 │ block4e_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_se_squeeze        │ (None, 512)            │              0 │ block4e_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_se_reshape        │ (None, 1, 1, 512)      │              0 │ block4e_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_se_reduce         │ (None, 1, 1, 32)       │         16,416 │ block4e_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_se_expand         │ (None, 1, 1, 512)      │         16,896 │ block4e_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_se_excite         │ (None, 16, 16, 512)    │              0 │ block4e_activation[0]… │
# │ (Multiply)                │                        │                │ block4e_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_project_conv      │ (None, 16, 16, 128)    │         65,536 │ block4e_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_project_bn        │ (None, 16, 16, 128)    │            512 │ block4e_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_drop (Dropout)    │ (None, 16, 16, 128)    │              0 │ block4e_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_add (Add)         │ (None, 16, 16, 128)    │              0 │ block4e_drop[0][0],    │
# │                           │                        │                │ block4d_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_expand_conv       │ (None, 16, 16, 512)    │         65,536 │ block4e_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_expand_bn         │ (None, 16, 16, 512)    │          2,048 │ block4f_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_expand_activation │ (None, 16, 16, 512)    │              0 │ block4f_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_dwconv2           │ (None, 16, 16, 512)    │          4,608 │ block4f_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_bn                │ (None, 16, 16, 512)    │          2,048 │ block4f_dwconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_activation        │ (None, 16, 16, 512)    │              0 │ block4f_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_se_squeeze        │ (None, 512)            │              0 │ block4f_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_se_reshape        │ (None, 1, 1, 512)      │              0 │ block4f_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_se_reduce         │ (None, 1, 1, 32)       │         16,416 │ block4f_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_se_expand         │ (None, 1, 1, 512)      │         16,896 │ block4f_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_se_excite         │ (None, 16, 16, 512)    │              0 │ block4f_activation[0]… │
# │ (Multiply)                │                        │                │ block4f_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_project_conv      │ (None, 16, 16, 128)    │         65,536 │ block4f_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_project_bn        │ (None, 16, 16, 128)    │            512 │ block4f_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_drop (Dropout)    │ (None, 16, 16, 128)    │              0 │ block4f_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_add (Add)         │ (None, 16, 16, 128)    │              0 │ block4f_drop[0][0],    │
# │                           │                        │                │ block4e_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_expand_conv       │ (None, 16, 16, 768)    │         98,304 │ block4f_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_expand_bn         │ (None, 16, 16, 768)    │          3,072 │ block5a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_expand_activation │ (None, 16, 16, 768)    │              0 │ block5a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_dwconv2           │ (None, 16, 16, 768)    │          6,912 │ block5a_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_bn                │ (None, 16, 16, 768)    │          3,072 │ block5a_dwconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_activation        │ (None, 16, 16, 768)    │              0 │ block5a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_se_squeeze        │ (None, 768)            │              0 │ block5a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_se_reshape        │ (None, 1, 1, 768)      │              0 │ block5a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_se_reduce         │ (None, 1, 1, 32)       │         24,608 │ block5a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_se_expand         │ (None, 1, 1, 768)      │         25,344 │ block5a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_se_excite         │ (None, 16, 16, 768)    │              0 │ block5a_activation[0]… │
# │ (Multiply)                │                        │                │ block5a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_project_conv      │ (None, 16, 16, 160)    │        122,880 │ block5a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_project_bn        │ (None, 16, 16, 160)    │            640 │ block5a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5b_expand_conv       │ (None, 16, 16, 960)    │        153,600 │ block5a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# ...
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6l_project_bn        │ (None, 8, 8, 256)      │          1,024 │ block6l_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6l_drop (Dropout)    │ (None, 8, 8, 256)      │              0 │ block6l_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6l_add (Add)         │ (None, 8, 8, 256)      │              0 │ block6l_drop[0][0],    │
# │                           │                        │                │ block6k_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_expand_conv       │ (None, 8, 8, 1536)     │        393,216 │ block6l_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_expand_bn         │ (None, 8, 8, 1536)     │          6,144 │ block6m_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_expand_activation │ (None, 8, 8, 1536)     │              0 │ block6m_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_dwconv2           │ (None, 8, 8, 1536)     │         13,824 │ block6m_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_bn                │ (None, 8, 8, 1536)     │          6,144 │ block6m_dwconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_activation        │ (None, 8, 8, 1536)     │              0 │ block6m_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_se_squeeze        │ (None, 1536)           │              0 │ block6m_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_se_reshape        │ (None, 1, 1, 1536)     │              0 │ block6m_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_se_reduce         │ (None, 1, 1, 64)       │         98,368 │ block6m_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_se_expand         │ (None, 1, 1, 1536)     │         99,840 │ block6m_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_se_excite         │ (None, 8, 8, 1536)     │              0 │ block6m_activation[0]… │
# │ (Multiply)                │                        │                │ block6m_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_project_conv      │ (None, 8, 8, 256)      │        393,216 │ block6m_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_project_bn        │ (None, 8, 8, 256)      │          1,024 │ block6m_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_drop (Dropout)    │ (None, 8, 8, 256)      │              0 │ block6m_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_add (Add)         │ (None, 8, 8, 256)      │              0 │ block6m_drop[0][0],    │
# │                           │                        │                │ block6l_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_expand_conv       │ (None, 8, 8, 1536)     │        393,216 │ block6m_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_expand_bn         │ (None, 8, 8, 1536)     │          6,144 │ block6n_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_expand_activation │ (None, 8, 8, 1536)     │              0 │ block6n_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_dwconv2           │ (None, 8, 8, 1536)     │         13,824 │ block6n_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_bn                │ (None, 8, 8, 1536)     │          6,144 │ block6n_dwconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_activation        │ (None, 8, 8, 1536)     │              0 │ block6n_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_se_squeeze        │ (None, 1536)           │              0 │ block6n_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_se_reshape        │ (None, 1, 1, 1536)     │              0 │ block6n_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_se_reduce         │ (None, 1, 1, 64)       │         98,368 │ block6n_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_se_expand         │ (None, 1, 1, 1536)     │         99,840 │ block6n_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_se_excite         │ (None, 8, 8, 1536)     │              0 │ block6n_activation[0]… │
# │ (Multiply)                │                        │                │ block6n_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_project_conv      │ (None, 8, 8, 256)      │        393,216 │ block6n_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_project_bn        │ (None, 8, 8, 256)      │          1,024 │ block6n_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_drop (Dropout)    │ (None, 8, 8, 256)      │              0 │ block6n_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_add (Add)         │ (None, 8, 8, 256)      │              0 │ block6n_drop[0][0],    │
# │                           │                        │                │ block6m_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_expand_conv       │ (None, 8, 8, 1536)     │        393,216 │ block6n_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_expand_bn         │ (None, 8, 8, 1536)     │          6,144 │ block6o_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_expand_activation │ (None, 8, 8, 1536)     │              0 │ block6o_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_dwconv2           │ (None, 8, 8, 1536)     │         13,824 │ block6o_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_bn                │ (None, 8, 8, 1536)     │          6,144 │ block6o_dwconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_activation        │ (None, 8, 8, 1536)     │              0 │ block6o_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_se_squeeze        │ (None, 1536)           │              0 │ block6o_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_se_reshape        │ (None, 1, 1, 1536)     │              0 │ block6o_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_se_reduce         │ (None, 1, 1, 64)       │         98,368 │ block6o_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_se_expand         │ (None, 1, 1, 1536)     │         99,840 │ block6o_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_se_excite         │ (None, 8, 8, 1536)     │              0 │ block6o_activation[0]… │
# │ (Multiply)                │                        │                │ block6o_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_project_conv      │ (None, 8, 8, 256)      │        393,216 │ block6o_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_project_bn        │ (None, 8, 8, 256)      │          1,024 │ block6o_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_drop (Dropout)    │ (None, 8, 8, 256)      │              0 │ block6o_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_add (Add)         │ (None, 8, 8, 256)      │              0 │ block6o_drop[0][0],    │
# │                           │                        │                │ block6n_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ top_conv (Conv2D)         │ (None, 8, 8, 1280)     │        327,680 │ block6o_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ top_bn                    │ (None, 8, 8, 1280)     │          5,120 │ top_conv[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ top_activation            │ (None, 8, 8, 1280)     │              0 │ top_bn[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 1280)           │              0 │ top_activation[0][0]   │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 512)            │        655,872 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 512)            │              0 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 256)            │        131,328 │ dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 256)            │              0 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 4)              │          1,028 │ dropout_1[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 21,119,588 (80.56 MB)
#  Trainable params: 788,228 (3.01 MB)
#  Non-trainable params: 20,331,360 (77.56 MB)

# %% [markdown]
# 기본학습에 에포크 5 추가

# %%
EPOCHS = 15  # 기본 전이 학습

history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=EPOCHS,
    verbose=1
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 125s 2s/step - accuracy: 0.4468 - loss: 1.2863 - val_accuracy: 0.5859 - val_loss: 0.8410
# Epoch 2/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 19s 623ms/step - accuracy: 0.5216 - loss: 1.1171 - val_accuracy: 0.6869 - val_loss: 0.8565
# Epoch 3/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 19s 622ms/step - accuracy: 0.5448 - loss: 1.0680 - val_accuracy: 0.6768 - val_loss: 0.8987
# Epoch 4/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 19s 619ms/step - accuracy: 0.5634 - loss: 1.0559 - val_accuracy: 0.7071 - val_loss: 0.8355
# Epoch 5/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 19s 622ms/step - accuracy: 0.5797 - loss: 1.0177 - val_accuracy: 0.6061 - val_loss: 0.8065
# Epoch 6/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 19s 619ms/step - accuracy: 0.5904 - loss: 0.9900 - val_accuracy: 0.7172 - val_loss: 0.8327
# Epoch 7/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 19s 618ms/step - accuracy: 0.6063 - loss: 0.9417 - val_accuracy: 0.6970 - val_loss: 0.7357
# Epoch 8/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 19s 626ms/step - accuracy: 0.6203 - loss: 0.9419 - val_accuracy: 0.7879 - val_loss: 0.7582
# Epoch 9/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 19s 624ms/step - accuracy: 0.6027 - loss: 0.9634 - val_accuracy: 0.8182 - val_loss: 0.7046
# Epoch 10/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 19s 622ms/step - accuracy: 0.6125 - loss: 0.9222 - val_accuracy: 0.7576 - val_loss: 0.6890
# Epoch 11/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 20s 628ms/step - accuracy: 0.6053 - loss: 0.9588 - val_accuracy: 0.7879 - val_loss: 0.6526
# Epoch 12/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 19s 625ms/step - accuracy: 0.6531 - loss: 0.8739 - val_accuracy: 0.7576 - val_loss: 0.7643
# Epoch 13/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 19s 622ms/step - accuracy: 0.6210 - loss: 0.9320 - val_accuracy: 0.7980 - val_loss: 0.7000
# Epoch 14/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 19s 622ms/step - accuracy: 0.6006 - loss: 0.9492 - val_accuracy: 0.7374 - val_loss: 0.6141
# Epoch 15/15
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 19s 628ms/step - accuracy: 0.6190 - loss: 0.9042 - val_accuracy: 0.7879 - val_loss: 0.7076

# %% [markdown]
# 상위 30%의 레이어를 학습 가능하도록 설정
# 2️⃣ 학습률(learning rate) 줄여 세밀한 조정 진행

# %%
# EfficientNetV2의 상위 30% 레이어를 학습 가능하게 변경
for layer in base_model.layers[-int(len(base_model.layers) * 0.3):]:
    layer.trainable = True

# 모델 재컴파일 (학습률 감소)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# 추가 학습 (Fine-Tuning)
EPOCHS_FINE_TUNE = 10  # 추가 학습 10 Epoch

history_finetune = model.fit(
    train_data,
    validation_data=val_data,
    epochs=EPOCHS_FINE_TUNE,
    verbose=1
)
# Out:
# Epoch 1/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - accuracy: 0.5290 - loss: 1.6124 - val_accuracy: 0.6566 - val_loss: 0.8477
# Epoch 2/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 19s 619ms/step - accuracy: 0.5613 - loss: 1.3843 - val_accuracy: 0.5960 - val_loss: 0.8805
# Epoch 3/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 19s 618ms/step - accuracy: 0.5427 - loss: 1.4072 - val_accuracy: 0.7071 - val_loss: 0.8183
# Epoch 4/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 19s 622ms/step - accuracy: 0.5740 - loss: 1.2264 - val_accuracy: 0.7172 - val_loss: 0.8138
# Epoch 5/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 19s 622ms/step - accuracy: 0.5336 - loss: 1.1958 - val_accuracy: 0.7374 - val_loss: 0.6799
# Epoch 6/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 19s 621ms/step - accuracy: 0.5724 - loss: 1.1649 - val_accuracy: 0.7677 - val_loss: 0.6641
# Epoch 7/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 19s 623ms/step - accuracy: 0.5473 - loss: 1.2358 - val_accuracy: 0.7778 - val_loss: 0.6551
# Epoch 8/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 20s 628ms/step - accuracy: 0.6033 - loss: 0.9869 - val_accuracy: 0.7374 - val_loss: 0.6346
# Epoch 9/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 19s 622ms/step - accuracy: 0.5861 - loss: 1.0654 - val_accuracy: 0.7273 - val_loss: 0.6713
# Epoch 10/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 20s 629ms/step - accuracy: 0.6262 - loss: 0.9441 - val_accuracy: 0.7677 - val_loss: 0.6238

# %%
import matplotlib.pyplot as plt

# 학습 결과 시각화
plt.figure(figsize=(12, 4))

# Loss 그래프
plt.subplot(1, 2, 1)
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.plot(history_finetune.history["loss"], label="Fine-Tune Train Loss", linestyle="dashed")
plt.plot(history_finetune.history["val_loss"], label="Fine-Tune Validation Loss", linestyle="dashed")
plt.legend()
plt.title("Loss Curve")

# Accuracy 그래프
plt.subplot(1, 2, 2)
plt.plot(history.history["accuracy"], label="Train Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
plt.plot(history_finetune.history["accuracy"], label="Fine-Tune Train Accuracy", linestyle="dashed")
plt.plot(history_finetune.history["val_accuracy"], label="Fine-Tune Validation Accuracy", linestyle="dashed")
plt.legend()
plt.title("Accuracy Curve")

plt.show()

# %%
# 검증 데이터 평가
val_loss, val_acc = model.evaluate(val_data)
print(f"✅ 최종 Validation Accuracy: {val_acc:.4f}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.7706 - loss: 0.6252
# ✅ 최종 Validation Accuracy: 0.7677

# %%
최종 결과 요약
✅ EfficientNetV2 + 고급 데이터 증강 + Fine-Tuning 적용
✅ 전이 학습 후 일부 레이어 해제하여 세밀한 학습 진행
✅ 기본 학습률보다 더 작은 학습률로 조정하여 성능 극대화

📌 기존 모델과 비교했을 때:

기존 모델 대비 Validation Accuracy 5~10% 향상 가능
과적합을 방지하는 Dropout 적용
데이터 증강을 더 강력하게 하여 일반화 성능 향상
