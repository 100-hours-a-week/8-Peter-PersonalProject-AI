# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/colab/orange-diseases-dataset.zip -d orange-diseases-dataset
# Out:
# Archive:  /content/drive/MyDrive/colab/orange-diseases-dataset.zip
#   inflating: orange-diseases-dataset/test/blackspot/b (1).jpg
#   inflating: orange-diseases-dataset/test/blackspot/b (10).jpg
#   inflating: orange-diseases-dataset/test/blackspot/b (11).jpg
#   inflating: orange-diseases-dataset/test/blackspot/b (12).jpg
#   inflating: orange-diseases-dataset/test/blackspot/b (13).jpg
#   inflating: orange-diseases-dataset/test/blackspot/b (14).jpg
#   inflating: orange-diseases-dataset/test/blackspot/b (15).jpg
#   inflating: orange-diseases-dataset/test/blackspot/b (16).jpg
#   inflating: orange-diseases-dataset/test/blackspot/b (17).jpg
#   inflating: orange-diseases-dataset/test/blackspot/b (18).jpg
#   inflating: orange-diseases-dataset/test/blackspot/b (19).jpg
#   inflating: orange-diseases-dataset/test/blackspot/b (2).jpg
#   inflating: orange-diseases-dataset/test/blackspot/b (20).jpg
#   inflating: orange-diseases-dataset/test/blackspot/b (21).jpg
#   inflating: orange-diseases-dataset/test/blackspot/b (22).jpg
#   inflating: orange-diseases-dataset/test/blackspot/b (3).jpg
#   inflating: orange-diseases-dataset/test/blackspot/b (4).jpg
#   inflating: orange-diseases-dataset/test/blackspot/b (5).jpg
#   inflating: orange-diseases-dataset/test/blackspot/b (6).jpg
#   inflating: orange-diseases-dataset/test/blackspot/b (7).jpg
#   inflating: orange-diseases-dataset/test/blackspot/b (8).jpg
#   inflating: orange-diseases-dataset/test/blackspot/b (9).jpg
#   inflating: orange-diseases-dataset/test/canker/c (1).jpg
#   inflating: orange-diseases-dataset/test/canker/c (10).jpg
#   inflating: orange-diseases-dataset/test/canker/c (11).jpg
#   inflating: orange-diseases-dataset/test/canker/c (12).jpg
#   inflating: orange-diseases-dataset/test/canker/c (13).jpg
#   inflating: orange-diseases-dataset/test/canker/c (14).jpg
#   inflating: orange-diseases-dataset/test/canker/c (15).jpg
#   inflating: orange-diseases-dataset/test/canker/c (16).jpg
#   inflating: orange-diseases-dataset/test/canker/c (17).jpg
#   inflating: orange-diseases-dataset/test/canker/c (18).jpg
#   inflating: orange-diseases-dataset/test/canker/c (19).jpg
#   inflating: orange-diseases-dataset/test/canker/c (2).jpg
#   inflating: orange-diseases-dataset/test/canker/c (20).jpg
#   inflating: orange-diseases-dataset/test/canker/c (21).jpg
#   inflating: orange-diseases-dataset/test/canker/c (22).jpg
#   inflating: orange-diseases-dataset/test/canker/c (3).jpg
#   inflating: orange-diseases-dataset/test/canker/c (4).jpg
#   inflating: orange-diseases-dataset/test/canker/c (5).jpg
#   inflating: orange-diseases-dataset/test/canker/c (6).jpg
#   inflating: orange-diseases-dataset/test/canker/c (7).jpg
#   inflating: orange-diseases-dataset/test/canker/c (8).jpg
#   inflating: orange-diseases-dataset/test/canker/c (9).jpg
#   inflating: orange-diseases-dataset/test/fresh/f (1).png
#   inflating: orange-diseases-dataset/test/fresh/f (10).png
#   inflating: orange-diseases-dataset/test/fresh/f (11).png
#   inflating: orange-diseases-dataset/test/fresh/f (12).png
#   inflating: orange-diseases-dataset/test/fresh/f (13).png
#   inflating: orange-diseases-dataset/test/fresh/f (14).png
#   inflating: orange-diseases-dataset/test/fresh/f (15).png
#   inflating: orange-diseases-dataset/test/fresh/f (16).png
#   inflating: orange-diseases-dataset/test/fresh/f (17).png
#   inflating: orange-diseases-dataset/test/fresh/f (18).png
#   inflating: orange-diseases-dataset/test/fresh/f (19).png
#   inflating: orange-diseases-dataset/test/fresh/f (2).png
#   inflating: orange-diseases-dataset/test/fresh/f (20).png
#   inflating: orange-diseases-dataset/test/fresh/f (21).png
#   inflating: orange-diseases-dataset/test/fresh/f (22).png
#   inflating: orange-diseases-dataset/test/fresh/f (23).png
#   inflating: orange-diseases-dataset/test/fresh/f (24).png
#   inflating: orange-diseases-dataset/test/fresh/f (25).png
#   inflating: orange-diseases-dataset/test/fresh/f (26).png
#   inflating: orange-diseases-dataset/test/fresh/f (27).png
#   inflating: orange-diseases-dataset/test/fresh/f (28).png
#   inflating: orange-diseases-dataset/test/fresh/f (29).png
#   inflating: orange-diseases-dataset/test/fresh/f (3).png
#   inflating: orange-diseases-dataset/test/fresh/f (30).png
#   inflating: orange-diseases-dataset/test/fresh/f (31).png
#   inflating: orange-diseases-dataset/test/fresh/f (32).png
#   inflating: orange-diseases-dataset/test/fresh/f (33).png
#   inflating: orange-diseases-dataset/test/fresh/f (4).png
#   inflating: orange-diseases-dataset/test/fresh/f (5).png
#   inflating: orange-diseases-dataset/test/fresh/f (6).png
#   inflating: orange-diseases-dataset/test/fresh/f (7).png
#   inflating: orange-diseases-dataset/test/fresh/f (8).png
#   inflating: orange-diseases-dataset/test/fresh/f (9).png
#   inflating: orange-diseases-dataset/test/grenning/g (1).jpg
#   inflating: orange-diseases-dataset/test/grenning/g (10).jpg
#   inflating: orange-diseases-dataset/test/grenning/g (11).jpg
#   inflating: orange-diseases-dataset/test/grenning/g (12).jpg
#   inflating: orange-diseases-dataset/test/grenning/g (13).jpg
#   inflating: orange-diseases-dataset/test/grenning/g (14).jpg
#   inflating: orange-diseases-dataset/test/grenning/g (15).jpg
#   inflating: orange-diseases-dataset/test/grenning/g (16).jpg
#   inflating: orange-diseases-dataset/test/grenning/g (17).jpg
#   inflating: orange-diseases-dataset/test/grenning/g (18).jpg
#   inflating: orange-diseases-dataset/test/grenning/g (19).jpg
#   inflating: orange-diseases-dataset/test/grenning/g (2).jpg
#   inflating: orange-diseases-dataset/test/grenning/g (20).jpg
#   inflating: orange-diseases-dataset/test/grenning/g (21).jpg
#   inflating: orange-diseases-dataset/test/grenning/g (22).jpg
#   inflating: orange-diseases-dataset/test/grenning/g (3).jpg
#   inflating: orange-diseases-dataset/test/grenning/g (4).jpg
#   inflating: orange-diseases-dataset/test/grenning/g (5).jpg
#   inflating: orange-diseases-dataset/test/grenning/g (6).jpg
#   inflating: orange-diseases-dataset/test/grenning/g (7).jpg
#   inflating: orange-diseases-dataset/test/grenning/g (8).jpg
#   inflating: orange-diseases-dataset/test/grenning/g (9).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (1).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (10).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (100).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (101).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (102).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (103).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (104).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (105).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (106).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (107).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (108).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (109).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (11).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (110).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (111).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (112).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (113).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (114).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (115).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (116).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (117).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (118).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (119).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (12).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (120).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (121).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (122).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (123).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (124).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (125).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (126).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (127).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (128).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (129).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (13).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (130).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (131).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (132).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (133).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (134).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (135).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (136).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (137).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (138).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (139).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (14).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (140).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (141).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (142).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (143).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (144).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (145).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (146).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (147).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (148).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (149).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (15).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (150).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (151).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (152).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (153).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (154).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (155).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (156).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (157).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (158).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (159).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (16).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (160).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (161).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (162).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (163).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (164).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (165).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (166).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (167).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (168).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (169).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (17).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (170).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (171).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (172).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (173).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (174).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (175).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (176).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (177).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (178).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (179).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (18).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (180).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (181).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (182).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (183).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (184).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (19).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (2).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (20).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (21).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (22).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (23).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (24).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (25).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (26).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (27).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (28).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (29).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (3).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (30).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (31).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (32).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (33).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (34).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (35).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (36).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (37).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (38).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (39).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (4).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (40).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (41).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (42).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (43).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (44).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (45).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (46).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (47).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (48).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (49).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (5).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (50).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (51).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (52).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (53).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (54).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (55).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (56).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (57).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (58).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (59).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (6).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (60).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (61).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (62).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (63).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (64).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (65).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (66).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (67).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (68).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (69).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (7).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (70).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (71).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (72).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (73).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (74).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (75).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (76).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (77).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (78).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (79).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (8).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (80).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (81).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (82).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (83).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (84).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (85).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (86).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (87).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (88).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (89).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (9).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (90).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (91).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (92).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (93).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (94).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (95).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (96).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (97).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (98).jpg
#   inflating: orange-diseases-dataset/train/blackspot/b (99).jpg
#   inflating: orange-diseases-dataset/train/canker/c (1).jpg
#   inflating: orange-diseases-dataset/train/canker/c (10).jpg
#   inflating: orange-diseases-dataset/train/canker/c (100).jpg
#   inflating: orange-diseases-dataset/train/canker/c (101).jpg
#   inflating: orange-diseases-dataset/train/canker/c (102).jpg
#   inflating: orange-diseases-dataset/train/canker/c (103).jpg
#   inflating: orange-diseases-dataset/train/canker/c (104).jpg
#   inflating: orange-diseases-dataset/train/canker/c (105).jpg
#   inflating: orange-diseases-dataset/train/canker/c (106).jpg
#   inflating: orange-diseases-dataset/train/canker/c (107).jpg
#   inflating: orange-diseases-dataset/train/canker/c (108).jpg
#   inflating: orange-diseases-dataset/train/canker/c (109).jpg
#   inflating: orange-diseases-dataset/train/canker/c (11).jpg
#   inflating: orange-diseases-dataset/train/canker/c (110).jpg
#   inflating: orange-diseases-dataset/train/canker/c (111).jpg
#   inflating: orange-diseases-dataset/train/canker/c (112).jpg
#   inflating: orange-diseases-dataset/train/canker/c (113).jpg
#   inflating: orange-diseases-dataset/train/canker/c (114).jpg
#   inflating: orange-diseases-dataset/train/canker/c (115).jpg
#   inflating: orange-diseases-dataset/train/canker/c (116).jpg
#   inflating: orange-diseases-dataset/train/canker/c (117).jpg
#   inflating: orange-diseases-dataset/train/canker/c (118).jpg
#   inflating: orange-diseases-dataset/train/canker/c (119).jpg
#   inflating: orange-diseases-dataset/train/canker/c (12).jpg
#   inflating: orange-diseases-dataset/train/canker/c (120).jpg
#   inflating: orange-diseases-dataset/train/canker/c (121).jpg
#   inflating: orange-diseases-dataset/train/canker/c (122).jpg
#   inflating: orange-diseases-dataset/train/canker/c (123).jpg
#   inflating: orange-diseases-dataset/train/canker/c (124).jpg
#   inflating: orange-diseases-dataset/train/canker/c (125).jpg
#   inflating: orange-diseases-dataset/train/canker/c (126).jpg
#   inflating: orange-diseases-dataset/train/canker/c (127).jpg
#   inflating: orange-diseases-dataset/train/canker/c (128).jpg
#   inflating: orange-diseases-dataset/train/canker/c (129).jpg
#   inflating: orange-diseases-dataset/train/canker/c (13).jpg
#   inflating: orange-diseases-dataset/train/canker/c (130).jpg
#   inflating: orange-diseases-dataset/train/canker/c (131).jpg
#   inflating: orange-diseases-dataset/train/canker/c (132).jpg
#   inflating: orange-diseases-dataset/train/canker/c (133).jpg
#   inflating: orange-diseases-dataset/train/canker/c (134).jpg
#   inflating: orange-diseases-dataset/train/canker/c (135).jpg
#   inflating: orange-diseases-dataset/train/canker/c (136).jpg
#   inflating: orange-diseases-dataset/train/canker/c (137).jpg
#   inflating: orange-diseases-dataset/train/canker/c (138).jpg
#   inflating: orange-diseases-dataset/train/canker/c (139).jpg
#   inflating: orange-diseases-dataset/train/canker/c (14).jpg
#   inflating: orange-diseases-dataset/train/canker/c (140).jpg
#   inflating: orange-diseases-dataset/train/canker/c (141).jpg
#   inflating: orange-diseases-dataset/train/canker/c (142).jpg
#   inflating: orange-diseases-dataset/train/canker/c (143).jpg
#   inflating: orange-diseases-dataset/train/canker/c (144).jpg
#   inflating: orange-diseases-dataset/train/canker/c (145).jpg
#   inflating: orange-diseases-dataset/train/canker/c (146).jpg
#   inflating: orange-diseases-dataset/train/canker/c (147).jpg
#   inflating: orange-diseases-dataset/train/canker/c (148).jpg
#   inflating: orange-diseases-dataset/train/canker/c (149).jpg
#   inflating: orange-diseases-dataset/train/canker/c (15).jpg
#   inflating: orange-diseases-dataset/train/canker/c (150).jpg
#   inflating: orange-diseases-dataset/train/canker/c (151).jpg
#   inflating: orange-diseases-dataset/train/canker/c (152).jpg
#   inflating: orange-diseases-dataset/train/canker/c (153).jpg
#   inflating: orange-diseases-dataset/train/canker/c (154).jpg
#   inflating: orange-diseases-dataset/train/canker/c (155).jpg
#   inflating: orange-diseases-dataset/train/canker/c (156).jpg
#   inflating: orange-diseases-dataset/train/canker/c (157).jpg
#   inflating: orange-diseases-dataset/train/canker/c (158).jpg
#   inflating: orange-diseases-dataset/train/canker/c (159).jpg
#   inflating: orange-diseases-dataset/train/canker/c (16).jpg
#   inflating: orange-diseases-dataset/train/canker/c (160).jpg
#   inflating: orange-diseases-dataset/train/canker/c (161).jpg
#   inflating: orange-diseases-dataset/train/canker/c (162).jpg
#   inflating: orange-diseases-dataset/train/canker/c (163).jpg
#   inflating: orange-diseases-dataset/train/canker/c (164).jpg
#   inflating: orange-diseases-dataset/train/canker/c (165).jpg
#   inflating: orange-diseases-dataset/train/canker/c (166).jpg
#   inflating: orange-diseases-dataset/train/canker/c (167).jpg
#   inflating: orange-diseases-dataset/train/canker/c (168).jpg
#   inflating: orange-diseases-dataset/train/canker/c (169).jpg
#   inflating: orange-diseases-dataset/train/canker/c (17).jpg
#   inflating: orange-diseases-dataset/train/canker/c (170).jpg
#   inflating: orange-diseases-dataset/train/canker/c (171).jpg
#   inflating: orange-diseases-dataset/train/canker/c (172).jpg
#   inflating: orange-diseases-dataset/train/canker/c (173).jpg
#   inflating: orange-diseases-dataset/train/canker/c (174).jpg
#   inflating: orange-diseases-dataset/train/canker/c (175).jpg
#   inflating: orange-diseases-dataset/train/canker/c (176).jpg
#   inflating: orange-diseases-dataset/train/canker/c (177).jpg
#   inflating: orange-diseases-dataset/train/canker/c (178).jpg
#   inflating: orange-diseases-dataset/train/canker/c (179).jpg
#   inflating: orange-diseases-dataset/train/canker/c (18).jpg
#   inflating: orange-diseases-dataset/train/canker/c (19).jpg
#   inflating: orange-diseases-dataset/train/canker/c (2).jpg
#   inflating: orange-diseases-dataset/train/canker/c (20).jpg
#   inflating: orange-diseases-dataset/train/canker/c (21).jpg
#   inflating: orange-diseases-dataset/train/canker/c (22).jpg
#   inflating: orange-diseases-dataset/train/canker/c (23).jpg
#   inflating: orange-diseases-dataset/train/canker/c (24).jpg
#   inflating: orange-diseases-dataset/train/canker/c (25).jpg
#   inflating: orange-diseases-dataset/train/canker/c (26).jpg
#   inflating: orange-diseases-dataset/train/canker/c (27).jpg
#   inflating: orange-diseases-dataset/train/canker/c (28).jpg
#   inflating: orange-diseases-dataset/train/canker/c (29).jpg
#   inflating: orange-diseases-dataset/train/canker/c (3).jpg
#   inflating: orange-diseases-dataset/train/canker/c (30).jpg
#   inflating: orange-diseases-dataset/train/canker/c (31).jpg
#   inflating: orange-diseases-dataset/train/canker/c (32).jpg
#   inflating: orange-diseases-dataset/train/canker/c (33).jpg
#   inflating: orange-diseases-dataset/train/canker/c (34).jpg
#   inflating: orange-diseases-dataset/train/canker/c (35).jpg
#   inflating: orange-diseases-dataset/train/canker/c (36).jpg
#   inflating: orange-diseases-dataset/train/canker/c (37).jpg
#   inflating: orange-diseases-dataset/train/canker/c (38).jpg
#   inflating: orange-diseases-dataset/train/canker/c (39).jpg
#   inflating: orange-diseases-dataset/train/canker/c (4).jpg
#   inflating: orange-diseases-dataset/train/canker/c (40).jpg
#   inflating: orange-diseases-dataset/train/canker/c (41).jpg
#   inflating: orange-diseases-dataset/train/canker/c (42).jpg
#   inflating: orange-diseases-dataset/train/canker/c (43).jpg
#   inflating: orange-diseases-dataset/train/canker/c (44).jpg
#   inflating: orange-diseases-dataset/train/canker/c (45).jpg
#   inflating: orange-diseases-dataset/train/canker/c (46).jpg
#   inflating: orange-diseases-dataset/train/canker/c (47).jpg
#   inflating: orange-diseases-dataset/train/canker/c (48).jpg
#   inflating: orange-diseases-dataset/train/canker/c (49).jpg
#   inflating: orange-diseases-dataset/train/canker/c (5).jpg
#   inflating: orange-diseases-dataset/train/canker/c (50).jpg
#   inflating: orange-diseases-dataset/train/canker/c (51).jpg
#   inflating: orange-diseases-dataset/train/canker/c (52).jpg
#   inflating: orange-diseases-dataset/train/canker/c (53).jpg
#   inflating: orange-diseases-dataset/train/canker/c (54).jpg
#   inflating: orange-diseases-dataset/train/canker/c (55).jpg
#   inflating: orange-diseases-dataset/train/canker/c (56).jpg
#   inflating: orange-diseases-dataset/train/canker/c (57).jpg
#   inflating: orange-diseases-dataset/train/canker/c (58).jpg
#   inflating: orange-diseases-dataset/train/canker/c (59).jpg
#   inflating: orange-diseases-dataset/train/canker/c (6).jpg
#   inflating: orange-diseases-dataset/train/canker/c (60).jpg
#   inflating: orange-diseases-dataset/train/canker/c (61).jpg
#   inflating: orange-diseases-dataset/train/canker/c (62).jpg
#   inflating: orange-diseases-dataset/train/canker/c (63).jpg
#   inflating: orange-diseases-dataset/train/canker/c (64).jpg
#   inflating: orange-diseases-dataset/train/canker/c (65).jpg
#   inflating: orange-diseases-dataset/train/canker/c (66).jpg
#   inflating: orange-diseases-dataset/train/canker/c (67).jpg
#   inflating: orange-diseases-dataset/train/canker/c (68).jpg
#   inflating: orange-diseases-dataset/train/canker/c (69).jpg
#   inflating: orange-diseases-dataset/train/canker/c (7).jpg
#   inflating: orange-diseases-dataset/train/canker/c (70).jpg
#   inflating: orange-diseases-dataset/train/canker/c (71).jpg
#   inflating: orange-diseases-dataset/train/canker/c (72).jpg
#   inflating: orange-diseases-dataset/train/canker/c (73).jpg
#   inflating: orange-diseases-dataset/train/canker/c (74).jpg
#   inflating: orange-diseases-dataset/train/canker/c (75).jpg
#   inflating: orange-diseases-dataset/train/canker/c (76).jpg
#   inflating: orange-diseases-dataset/train/canker/c (77).jpg
#   inflating: orange-diseases-dataset/train/canker/c (78).jpg
#   inflating: orange-diseases-dataset/train/canker/c (79).jpg
#   inflating: orange-diseases-dataset/train/canker/c (8).jpg
#   inflating: orange-diseases-dataset/train/canker/c (80).jpg
#   inflating: orange-diseases-dataset/train/canker/c (81).jpg
#   inflating: orange-diseases-dataset/train/canker/c (82).jpg
#   inflating: orange-diseases-dataset/train/canker/c (83).jpg
#   inflating: orange-diseases-dataset/train/canker/c (84).jpg
#   inflating: orange-diseases-dataset/train/canker/c (85).jpg
#   inflating: orange-diseases-dataset/train/canker/c (86).jpg
#   inflating: orange-diseases-dataset/train/canker/c (87).jpg
#   inflating: orange-diseases-dataset/train/canker/c (88).jpg
#   inflating: orange-diseases-dataset/train/canker/c (89).jpg
#   inflating: orange-diseases-dataset/train/canker/c (9).jpg
#   inflating: orange-diseases-dataset/train/canker/c (90).jpg
#   inflating: orange-diseases-dataset/train/canker/c (91).jpg
#   inflating: orange-diseases-dataset/train/canker/c (92).jpg
#   inflating: orange-diseases-dataset/train/canker/c (93).jpg
#   inflating: orange-diseases-dataset/train/canker/c (94).jpg
#   inflating: orange-diseases-dataset/train/canker/c (95).jpg
#   inflating: orange-diseases-dataset/train/canker/c (96).jpg
#   inflating: orange-diseases-dataset/train/canker/c (97).jpg
#   inflating: orange-diseases-dataset/train/canker/c (98).jpg
#   inflating: orange-diseases-dataset/train/canker/c (99).jpg
#   inflating: orange-diseases-dataset/train/fresh/f (1).png
#   inflating: orange-diseases-dataset/train/fresh/f (10).png
#   inflating: orange-diseases-dataset/train/fresh/f (100).png
#   inflating: orange-diseases-dataset/train/fresh/f (101).png
#   inflating: orange-diseases-dataset/train/fresh/f (102).png
#   inflating: orange-diseases-dataset/train/fresh/f (103).png
#   inflating: orange-diseases-dataset/train/fresh/f (104).png
#   inflating: orange-diseases-dataset/train/fresh/f (105).png
#   inflating: orange-diseases-dataset/train/fresh/f (106).png
#   inflating: orange-diseases-dataset/train/fresh/f (107).png
#   inflating: orange-diseases-dataset/train/fresh/f (108).png
#   inflating: orange-diseases-dataset/train/fresh/f (109).png
#   inflating: orange-diseases-dataset/train/fresh/f (11).png
#   inflating: orange-diseases-dataset/train/fresh/f (110).png
#   inflating: orange-diseases-dataset/train/fresh/f (111).png
#   inflating: orange-diseases-dataset/train/fresh/f (112).png
#   inflating: orange-diseases-dataset/train/fresh/f (113).png
#   inflating: orange-diseases-dataset/train/fresh/f (114).png
#   inflating: orange-diseases-dataset/train/fresh/f (115).png
#   inflating: orange-diseases-dataset/train/fresh/f (116).png
#   inflating: orange-diseases-dataset/train/fresh/f (117).png
#   inflating: orange-diseases-dataset/train/fresh/f (118).png
#   inflating: orange-diseases-dataset/train/fresh/f (119).png
#   inflating: orange-diseases-dataset/train/fresh/f (12).png
#   inflating: orange-diseases-dataset/train/fresh/f (120).png
#   inflating: orange-diseases-dataset/train/fresh/f (121).png
#   inflating: orange-diseases-dataset/train/fresh/f (122).png
#   inflating: orange-diseases-dataset/train/fresh/f (123).png
#   inflating: orange-diseases-dataset/train/fresh/f (124).png
#   inflating: orange-diseases-dataset/train/fresh/f (125).png
#   inflating: orange-diseases-dataset/train/fresh/f (126).png
#   inflating: orange-diseases-dataset/train/fresh/f (127).png
#   inflating: orange-diseases-dataset/train/fresh/f (128).png
#   inflating: orange-diseases-dataset/train/fresh/f (129).png
#   inflating: orange-diseases-dataset/train/fresh/f (13).png
#   inflating: orange-diseases-dataset/train/fresh/f (130).png
#   inflating: orange-diseases-dataset/train/fresh/f (131).png
#   inflating: orange-diseases-dataset/train/fresh/f (132).png
#   inflating: orange-diseases-dataset/train/fresh/f (133).png
#   inflating: orange-diseases-dataset/train/fresh/f (134).png
#   inflating: orange-diseases-dataset/train/fresh/f (135).png
#   inflating: orange-diseases-dataset/train/fresh/f (136).png
#   inflating: orange-diseases-dataset/train/fresh/f (137).png
#   inflating: orange-diseases-dataset/train/fresh/f (138).png
#   inflating: orange-diseases-dataset/train/fresh/f (139).png
#   inflating: orange-diseases-dataset/train/fresh/f (14).png
#   inflating: orange-diseases-dataset/train/fresh/f (140).png
#   inflating: orange-diseases-dataset/train/fresh/f (141).png
#   inflating: orange-diseases-dataset/train/fresh/f (142).png
#   inflating: orange-diseases-dataset/train/fresh/f (143).png
#   inflating: orange-diseases-dataset/train/fresh/f (144).png
#   inflating: orange-diseases-dataset/train/fresh/f (145).png
#   inflating: orange-diseases-dataset/train/fresh/f (146).png
#   inflating: orange-diseases-dataset/train/fresh/f (147).png
#   inflating: orange-diseases-dataset/train/fresh/f (148).png
#   inflating: orange-diseases-dataset/train/fresh/f (149).png
#   inflating: orange-diseases-dataset/train/fresh/f (15).png
#   inflating: orange-diseases-dataset/train/fresh/f (150).png
#   inflating: orange-diseases-dataset/train/fresh/f (151).png
#   inflating: orange-diseases-dataset/train/fresh/f (152).png
#   inflating: orange-diseases-dataset/train/fresh/f (153).png
#   inflating: orange-diseases-dataset/train/fresh/f (154).png
#   inflating: orange-diseases-dataset/train/fresh/f (155).png
#   inflating: orange-diseases-dataset/train/fresh/f (156).png
#   inflating: orange-diseases-dataset/train/fresh/f (157).png
#   inflating: orange-diseases-dataset/train/fresh/f (158).png
#   inflating: orange-diseases-dataset/train/fresh/f (159).png
#   inflating: orange-diseases-dataset/train/fresh/f (16).png
#   inflating: orange-diseases-dataset/train/fresh/f (160).png
#   inflating: orange-diseases-dataset/train/fresh/f (161).png
#   inflating: orange-diseases-dataset/train/fresh/f (162).png
#   inflating: orange-diseases-dataset/train/fresh/f (163).png
#   inflating: orange-diseases-dataset/train/fresh/f (164).png
#   inflating: orange-diseases-dataset/train/fresh/f (165).png
#   inflating: orange-diseases-dataset/train/fresh/f (166).png
#   inflating: orange-diseases-dataset/train/fresh/f (167).png
#   inflating: orange-diseases-dataset/train/fresh/f (168).png
#   inflating: orange-diseases-dataset/train/fresh/f (169).png
#   inflating: orange-diseases-dataset/train/fresh/f (17).png
#   inflating: orange-diseases-dataset/train/fresh/f (170).png
#   inflating: orange-diseases-dataset/train/fresh/f (171).png
#   inflating: orange-diseases-dataset/train/fresh/f (172).png
#   inflating: orange-diseases-dataset/train/fresh/f (173).png
#   inflating: orange-diseases-dataset/train/fresh/f (174).png
#   inflating: orange-diseases-dataset/train/fresh/f (175).png
#   inflating: orange-diseases-dataset/train/fresh/f (176).png
#   inflating: orange-diseases-dataset/train/fresh/f (177).png
#   inflating: orange-diseases-dataset/train/fresh/f (178).png
#   inflating: orange-diseases-dataset/train/fresh/f (179).png
#   inflating: orange-diseases-dataset/train/fresh/f (18).png
#   inflating: orange-diseases-dataset/train/fresh/f (180).png
#   inflating: orange-diseases-dataset/train/fresh/f (181).png
#   inflating: orange-diseases-dataset/train/fresh/f (182).png
#   inflating: orange-diseases-dataset/train/fresh/f (183).png
#   inflating: orange-diseases-dataset/train/fresh/f (184).png
#   inflating: orange-diseases-dataset/train/fresh/f (185).png
#   inflating: orange-diseases-dataset/train/fresh/f (186).png
#   inflating: orange-diseases-dataset/train/fresh/f (187).png
#   inflating: orange-diseases-dataset/train/fresh/f (188).png
#   inflating: orange-diseases-dataset/train/fresh/f (189).png
#   inflating: orange-diseases-dataset/train/fresh/f (19).png
#   inflating: orange-diseases-dataset/train/fresh/f (190).png
#   inflating: orange-diseases-dataset/train/fresh/f (191).png
#   inflating: orange-diseases-dataset/train/fresh/f (192).png
#   inflating: orange-diseases-dataset/train/fresh/f (193).png
#   inflating: orange-diseases-dataset/train/fresh/f (194).png
#   inflating: orange-diseases-dataset/train/fresh/f (195).png
#   inflating: orange-diseases-dataset/train/fresh/f (196).png
#   inflating: orange-diseases-dataset/train/fresh/f (197).png
#   inflating: orange-diseases-dataset/train/fresh/f (198).png
#   inflating: orange-diseases-dataset/train/fresh/f (199).png
#   inflating: orange-diseases-dataset/train/fresh/f (2).png
#   inflating: orange-diseases-dataset/train/fresh/f (20).png
#   inflating: orange-diseases-dataset/train/fresh/f (200).png
#   inflating: orange-diseases-dataset/train/fresh/f (201).png
#   inflating: orange-diseases-dataset/train/fresh/f (202).png
#   inflating: orange-diseases-dataset/train/fresh/f (203).png
#   inflating: orange-diseases-dataset/train/fresh/f (204).png
#   inflating: orange-diseases-dataset/train/fresh/f (205).png
#   inflating: orange-diseases-dataset/train/fresh/f (206).png
#   inflating: orange-diseases-dataset/train/fresh/f (207).png
#   inflating: orange-diseases-dataset/train/fresh/f (208).png
#   inflating: orange-diseases-dataset/train/fresh/f (209).png
#   inflating: orange-diseases-dataset/train/fresh/f (21).png
#   inflating: orange-diseases-dataset/train/fresh/f (210).png
#   inflating: orange-diseases-dataset/train/fresh/f (211).png
#   inflating: orange-diseases-dataset/train/fresh/f (212).png
#   inflating: orange-diseases-dataset/train/fresh/f (213).png
#   inflating: orange-diseases-dataset/train/fresh/f (214).png
#   inflating: orange-diseases-dataset/train/fresh/f (215).png
#   inflating: orange-diseases-dataset/train/fresh/f (216).png
#   inflating: orange-diseases-dataset/train/fresh/f (217).png
#   inflating: orange-diseases-dataset/train/fresh/f (218).png
#   inflating: orange-diseases-dataset/train/fresh/f (219).png
#   inflating: orange-diseases-dataset/train/fresh/f (22).png
#   inflating: orange-diseases-dataset/train/fresh/f (220).png
#   inflating: orange-diseases-dataset/train/fresh/f (221).png
#   inflating: orange-diseases-dataset/train/fresh/f (222).png
#   inflating: orange-diseases-dataset/train/fresh/f (223).png
#   inflating: orange-diseases-dataset/train/fresh/f (224).png
#   inflating: orange-diseases-dataset/train/fresh/f (225).png
#   inflating: orange-diseases-dataset/train/fresh/f (226).png
#   inflating: orange-diseases-dataset/train/fresh/f (227).png
#   inflating: orange-diseases-dataset/train/fresh/f (228).png
#   inflating: orange-diseases-dataset/train/fresh/f (229).png
#   inflating: orange-diseases-dataset/train/fresh/f (23).png
#   inflating: orange-diseases-dataset/train/fresh/f (230).png
#   inflating: orange-diseases-dataset/train/fresh/f (231).png
#   inflating: orange-diseases-dataset/train/fresh/f (232).png
#   inflating: orange-diseases-dataset/train/fresh/f (233).png
#   inflating: orange-diseases-dataset/train/fresh/f (234).png
#   inflating: orange-diseases-dataset/train/fresh/f (235).png
#   inflating: orange-diseases-dataset/train/fresh/f (236).png
#   inflating: orange-diseases-dataset/train/fresh/f (237).png
#   inflating: orange-diseases-dataset/train/fresh/f (238).png
#   inflating: orange-diseases-dataset/train/fresh/f (239).png
#   inflating: orange-diseases-dataset/train/fresh/f (24).png
#   inflating: orange-diseases-dataset/train/fresh/f (240).png
#   inflating: orange-diseases-dataset/train/fresh/f (241).png
#   inflating: orange-diseases-dataset/train/fresh/f (242).png
#   inflating: orange-diseases-dataset/train/fresh/f (243).png
#   inflating: orange-diseases-dataset/train/fresh/f (244).png
#   inflating: orange-diseases-dataset/train/fresh/f (245).png
#   inflating: orange-diseases-dataset/train/fresh/f (246).png
#   inflating: orange-diseases-dataset/train/fresh/f (247).png
#   inflating: orange-diseases-dataset/train/fresh/f (248).png
#   inflating: orange-diseases-dataset/train/fresh/f (249).png
#   inflating: orange-diseases-dataset/train/fresh/f (25).png
#   inflating: orange-diseases-dataset/train/fresh/f (250).png
#   inflating: orange-diseases-dataset/train/fresh/f (251).png
#   inflating: orange-diseases-dataset/train/fresh/f (252).png
#   inflating: orange-diseases-dataset/train/fresh/f (253).png
#   inflating: orange-diseases-dataset/train/fresh/f (254).png
#   inflating: orange-diseases-dataset/train/fresh/f (255).png
#   inflating: orange-diseases-dataset/train/fresh/f (256).png
#   inflating: orange-diseases-dataset/train/fresh/f (257).png
#   inflating: orange-diseases-dataset/train/fresh/f (258).png
#   inflating: orange-diseases-dataset/train/fresh/f (259).png
#   inflating: orange-diseases-dataset/train/fresh/f (26).png
#   inflating: orange-diseases-dataset/train/fresh/f (260).png
#   inflating: orange-diseases-dataset/train/fresh/f (261).png
#   inflating: orange-diseases-dataset/train/fresh/f (262).png
#   inflating: orange-diseases-dataset/train/fresh/f (263).png
#   inflating: orange-diseases-dataset/train/fresh/f (264).png
#   inflating: orange-diseases-dataset/train/fresh/f (265).png
#   inflating: orange-diseases-dataset/train/fresh/f (266).png
#   inflating: orange-diseases-dataset/train/fresh/f (267).png
#   inflating: orange-diseases-dataset/train/fresh/f (268).png
#   inflating: orange-diseases-dataset/train/fresh/f (269).png
#   inflating: orange-diseases-dataset/train/fresh/f (27).png
#   inflating: orange-diseases-dataset/train/fresh/f (270).png
#   inflating: orange-diseases-dataset/train/fresh/f (271).png
#   inflating: orange-diseases-dataset/train/fresh/f (272).png
#   inflating: orange-diseases-dataset/train/fresh/f (273).png
#   inflating: orange-diseases-dataset/train/fresh/f (274).png
#   inflating: orange-diseases-dataset/train/fresh/f (275).png
#   inflating: orange-diseases-dataset/train/fresh/f (276).png
#   inflating: orange-diseases-dataset/train/fresh/f (277).png
#   inflating: orange-diseases-dataset/train/fresh/f (278).png
#   inflating: orange-diseases-dataset/train/fresh/f (279).png
#   inflating: orange-diseases-dataset/train/fresh/f (28).png
#   inflating: orange-diseases-dataset/train/fresh/f (280).png
#   inflating: orange-diseases-dataset/train/fresh/f (281).png
#   inflating: orange-diseases-dataset/train/fresh/f (29).png
#   inflating: orange-diseases-dataset/train/fresh/f (3).png
#   inflating: orange-diseases-dataset/train/fresh/f (30).png
#   inflating: orange-diseases-dataset/train/fresh/f (31).png
#   inflating: orange-diseases-dataset/train/fresh/f (32).png
#   inflating: orange-diseases-dataset/train/fresh/f (33).png
#   inflating: orange-diseases-dataset/train/fresh/f (34).png
#   inflating: orange-diseases-dataset/train/fresh/f (35).png
#   inflating: orange-diseases-dataset/train/fresh/f (36).png
#   inflating: orange-diseases-dataset/train/fresh/f (37).png
#   inflating: orange-diseases-dataset/train/fresh/f (38).png
#   inflating: orange-diseases-dataset/train/fresh/f (39).png
#   inflating: orange-diseases-dataset/train/fresh/f (4).png
#   inflating: orange-diseases-dataset/train/fresh/f (40).png
#   inflating: orange-diseases-dataset/train/fresh/f (41).png
#   inflating: orange-diseases-dataset/train/fresh/f (42).png
#   inflating: orange-diseases-dataset/train/fresh/f (43).png
#   inflating: orange-diseases-dataset/train/fresh/f (44).png
#   inflating: orange-diseases-dataset/train/fresh/f (45).png
#   inflating: orange-diseases-dataset/train/fresh/f (46).png
#   inflating: orange-diseases-dataset/train/fresh/f (47).png
#   inflating: orange-diseases-dataset/train/fresh/f (48).png
#   inflating: orange-diseases-dataset/train/fresh/f (49).png
#   inflating: orange-diseases-dataset/train/fresh/f (5).png
#   inflating: orange-diseases-dataset/train/fresh/f (50).png
#   inflating: orange-diseases-dataset/train/fresh/f (51).png
#   inflating: orange-diseases-dataset/train/fresh/f (52).png
#   inflating: orange-diseases-dataset/train/fresh/f (53).png
#   inflating: orange-diseases-dataset/train/fresh/f (54).png
#   inflating: orange-diseases-dataset/train/fresh/f (55).png
#   inflating: orange-diseases-dataset/train/fresh/f (56).png
#   inflating: orange-diseases-dataset/train/fresh/f (57).png
#   inflating: orange-diseases-dataset/train/fresh/f (58).png
#   inflating: orange-diseases-dataset/train/fresh/f (59).png
#   inflating: orange-diseases-dataset/train/fresh/f (6).png
#   inflating: orange-diseases-dataset/train/fresh/f (60).png
#   inflating: orange-diseases-dataset/train/fresh/f (61).png
#   inflating: orange-diseases-dataset/train/fresh/f (62).png
#   inflating: orange-diseases-dataset/train/fresh/f (63).png
#   inflating: orange-diseases-dataset/train/fresh/f (64).png
#   inflating: orange-diseases-dataset/train/fresh/f (65).png
#   inflating: orange-diseases-dataset/train/fresh/f (66).png
#   inflating: orange-diseases-dataset/train/fresh/f (67).png
#   inflating: orange-diseases-dataset/train/fresh/f (68).png
#   inflating: orange-diseases-dataset/train/fresh/f (69).png
#   inflating: orange-diseases-dataset/train/fresh/f (7).png
#   inflating: orange-diseases-dataset/train/fresh/f (70).png
#   inflating: orange-diseases-dataset/train/fresh/f (71).png
#   inflating: orange-diseases-dataset/train/fresh/f (72).png
#   inflating: orange-diseases-dataset/train/fresh/f (73).png
#   inflating: orange-diseases-dataset/train/fresh/f (74).png
#   inflating: orange-diseases-dataset/train/fresh/f (75).png
#   inflating: orange-diseases-dataset/train/fresh/f (76).png
#   inflating: orange-diseases-dataset/train/fresh/f (77).png
#   inflating: orange-diseases-dataset/train/fresh/f (78).png
#   inflating: orange-diseases-dataset/train/fresh/f (79).png
#   inflating: orange-diseases-dataset/train/fresh/f (8).png
#   inflating: orange-diseases-dataset/train/fresh/f (80).png
#   inflating: orange-diseases-dataset/train/fresh/f (81).png
#   inflating: orange-diseases-dataset/train/fresh/f (82).png
#   inflating: orange-diseases-dataset/train/fresh/f (83).png
#   inflating: orange-diseases-dataset/train/fresh/f (84).png
#   inflating: orange-diseases-dataset/train/fresh/f (85).png
#   inflating: orange-diseases-dataset/train/fresh/f (86).png
#   inflating: orange-diseases-dataset/train/fresh/f (87).png
#   inflating: orange-diseases-dataset/train/fresh/f (88).png
#   inflating: orange-diseases-dataset/train/fresh/f (89).png
#   inflating: orange-diseases-dataset/train/fresh/f (9).png
#   inflating: orange-diseases-dataset/train/fresh/f (90).png
#   inflating: orange-diseases-dataset/train/fresh/f (91).png
#   inflating: orange-diseases-dataset/train/fresh/f (92).png
#   inflating: orange-diseases-dataset/train/fresh/f (93).png
#   inflating: orange-diseases-dataset/train/fresh/f (94).png
#   inflating: orange-diseases-dataset/train/fresh/f (95).png
#   inflating: orange-diseases-dataset/train/fresh/f (96).png
#   inflating: orange-diseases-dataset/train/fresh/f (97).png
#   inflating: orange-diseases-dataset/train/fresh/f (98).png
#   inflating: orange-diseases-dataset/train/fresh/f (99).png
#   inflating: orange-diseases-dataset/train/grenning/g (1).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (10).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (100).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (101).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (102).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (103).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (104).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (105).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (106).jpg
# ...
#   inflating: orange-diseases-dataset/train/grenning/g (193).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (194).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (195).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (196).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (197).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (198).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (199).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (2).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (20).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (200).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (201).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (202).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (203).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (204).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (205).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (206).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (207).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (208).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (209).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (21).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (210).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (211).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (212).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (213).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (214).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (215).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (216).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (217).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (218).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (219).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (22).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (220).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (221).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (222).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (223).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (224).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (225).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (226).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (227).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (228).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (229).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (23).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (230).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (231).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (232).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (233).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (234).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (235).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (236).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (237).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (238).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (239).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (24).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (240).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (241).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (242).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (243).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (244).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (245).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (246).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (247).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (248).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (249).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (25).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (250).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (251).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (252).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (253).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (254).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (255).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (256).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (257).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (258).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (259).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (26).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (260).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (261).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (262).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (263).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (264).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (265).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (266).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (267).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (268).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (269).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (27).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (270).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (271).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (272).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (273).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (274).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (275).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (276).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (277).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (278).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (279).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (28).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (280).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (281).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (282).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (283).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (284).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (285).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (286).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (287).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (288).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (289).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (29).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (290).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (291).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (292).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (293).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (294).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (295).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (296).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (297).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (298).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (299).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (3).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (30).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (300).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (301).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (302).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (303).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (304).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (305).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (306).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (307).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (308).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (309).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (31).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (310).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (311).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (312).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (313).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (314).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (315).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (316).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (317).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (318).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (319).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (32).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (320).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (321).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (322).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (323).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (324).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (325).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (326).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (327).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (328).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (329).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (33).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (330).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (331).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (332).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (333).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (334).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (335).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (336).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (337).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (338).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (339).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (34).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (340).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (341).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (342).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (343).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (344).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (345).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (346).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (347).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (35).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (36).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (37).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (38).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (39).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (4).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (40).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (41).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (42).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (43).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (44).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (45).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (46).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (47).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (48).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (49).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (5).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (50).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (51).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (52).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (53).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (54).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (55).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (56).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (57).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (58).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (59).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (6).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (60).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (61).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (62).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (63).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (64).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (65).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (66).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (67).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (68).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (69).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (7).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (70).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (71).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (72).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (73).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (74).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (75).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (76).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (77).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (78).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (79).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (8).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (80).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (81).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (82).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (83).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (84).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (85).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (86).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (87).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (88).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (89).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (9).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (90).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (91).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (92).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (93).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (94).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (95).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (96).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (97).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (98).jpg
#   inflating: orange-diseases-dataset/train/grenning/g (99).jpg

# %%
# !pip install "pymongo[srv]"==3.12
# Out:
# Collecting pymongo==3.12 (from pymongo[srv]==3.12)
#   Downloading pymongo-3.12.0.tar.gz (818 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 818.6/818.6 kB 32.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting dnspython<2.0.0,>=1.16.0 (from pymongo[srv]==3.12)
#   Downloading dnspython-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Downloading dnspython-1.16.0-py2.py3-none-any.whl (188 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.4/188.4 kB 13.7 MB/s eta 0:00:00
# Building wheels for collected packages: pymongo
#   Building wheel for pymongo (setup.py) ... done
#   Created wheel for pymongo: filename=pymongo-3.12.0-cp311-cp311-linux_x86_64.whl size=510593 sha256=7505f34be753eaf0b07c0d31e2b5311ac6d5394a089b713fe6ffbc4c3037e00e
#   Stored in directory: /root/.cache/pip/wheels/0a/e0/8a/adfa1aa746c3a9984d16be698311d2ba894032a3ca7cf400ed
# Successfully built pymongo
# Installing collected packages: pymongo, dnspython
#   Attempting uninstall: pymongo
#     Found existing installation: pymongo 4.11.3
#     Uninstalling pymongo-4.11.3:
#       Successfully uninstalled pymongo-4.11.3
#   Attempting uninstall: dnspython
#     Found existing installation: dnspython 2.7.0
#     Uninstalling dnspython-2.7.0:
#       Successfully uninstalled dnspython-2.7.0
# Successfully installed dnspython-1.16.0 pymongo-3.12.0

# %%
# !pip install pymongo
# !pip install --upgrade pymongo
# Out:
# Requirement already satisfied: pymongo in /usr/local/lib/python3.11/dist-packages (3.12.0)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.11/dist-packages (3.12.0)
# Collecting pymongo
#   Using cached pymongo-4.11.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from pymongo) (1.16.0)
# Using cached pymongo-4.11.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
# Installing collected packages: pymongo
#   Attempting uninstall: pymongo
#     Found existing installation: pymongo 3.12.0
#     Uninstalling pymongo-3.12.0:
#       Successfully uninstalled pymongo-3.12.0
# Successfully installed pymongo-4.11.3

# %%
# !sudo apt-get update
# !sudo apt-get install --reinstall ca-certificates
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,381 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,784 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [4,049 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [47.7 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [3,892 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,538 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,045 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [55.7 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [35.2 kB]
# Get:20 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,737 kB]
# Get:21 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,239 kB]
# Get:22 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,684 kB]
# Fetched 29.9 MB in 4s (7,460 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 0 upgraded, 0 newly installed, 1 reinstalled, 0 to remove and 38 not upgraded.
# Need to get 162 kB of archives.
# After this operation, 0 B of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ca-certificates all 20240203~22.04.1 [162 kB]
# Fetched 162 kB in 2s (107 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# (Reading database ... 126209 files and directories currently installed.)
# Preparing to unpack .../ca-certificates_20240203~22.04.1_all.deb ...
# Unpacking ca-certificates (20240203~22.04.1) over (20240203~22.04.1) ...
# Setting up ca-certificates (20240203~22.04.1) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# Updating certificates in /etc/ssl/certs...
# 0 added, 0 removed; done.
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for ca-certificates (20240203~22.04.1) ...
# Updating certificates in /etc/ssl/certs...
# 0 added, 0 removed; done.
# Running hooks in /etc/ca-certificates/update.d...
#
# done.
# done.

# %%
# !pip install --upgrade pymongo
# !sudo apt-get install --reinstall ca-certificates

from pymongo import MongoClient

try:
    client = MongoClient(
        "mongodb+srv://gwshim:2OtqnghbiSVMwW4q@cluster0.edb8j.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0",
        tls=True,
        tlsAllowInvalidCertificates=True  # ✅ TLS 문제 회피
    )
    db = client["pp-peter-api"]
    collection = db["ai-info"]
    collection.insert_one({"message": "Colab 연결 테스트 완료!"})
    print("✅ 연결 성공! 데이터 저장 완료")
except Exception as e:
    print("❌ 연결 실패:", e)
# Out:
# Requirement already satisfied: pymongo in /usr/local/lib/python3.11/dist-packages (4.11.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from pymongo) (1.16.0)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 0 upgraded, 0 newly installed, 1 reinstalled, 0 to remove and 38 not upgraded.
# Need to get 162 kB of archives.
# After this operation, 0 B of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ca-certificates all 20240203~22.04.1 [162 kB]
# Fetched 162 kB in 1s (125 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# (Reading database ... 126209 files and directories currently installed.)
# Preparing to unpack .../ca-certificates_20240203~22.04.1_all.deb ...
# Unpacking ca-certificates (20240203~22.04.1) over (20240203~22.04.1) ...
# Setting up ca-certificates (20240203~22.04.1) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# Updating certificates in /etc/ssl/certs...
# 0 added, 0 removed; done.
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for ca-certificates (20240203~22.04.1) ...
# Updating certificates in /etc/ssl/certs...
# 0 added, 0 removed; done.
# Running hooks in /etc/ca-certificates/update.d...
#
# done.
# done.
# ✅ 연결 성공! 데이터 저장 완료

# %%
import tensorflow as tf
import datetime
from datetime import datetime

class MongoLoggingCallback(tf.keras.callbacks.Callback):
    def on_epoch_begin(self, epoch, logs=None):
        self.epoch_start_time = datetime.utcnow()

    def on_epoch_end(self, epoch, logs=None):
        log = {
            "epoch": epoch + 1,
            "start_time": self.epoch_start_time,
            "end_time": datetime.utcnow(),
            "loss": logs.get("loss"),
            "val_loss": logs.get("val_loss"),
            "accuracy": logs.get("accuracy"),
            "val_accuracy": logs.get("val_accuracy"),
        }
        try:
            collection.insert_one(log)
            print(f"📤 MongoDB에 Epoch {epoch+1} 로그 저장됨")
        except Exception as e:
            print("❌ 로그 저장 실패:", e)

# %%
import os
import shutil
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# 데이터 경로 설정
data_dir = "/content/orange-diseases-dataset"
train_dir = os.path.join(data_dir, "train")
val_dir = os.path.join(data_dir, "val")

# 클래스 확인
classes = os.listdir(train_dir)
print("클래스 목록:", classes)
# Out:
# 클래스 목록: ['canker', 'grenning', 'fresh', 'blackspot']

# %%
# 이미지 크기 및 배치 설정
IMG_SIZE = (256, 256)
BATCH_SIZE = 32

# 데이터 증강 적용
train_datagen = ImageDataGenerator(
    rescale=1.0 / 255.0,
    rotation_range=30,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=0.2
)

val_datagen = ImageDataGenerator(rescale=1.0 / 255.0)

# 데이터 불러오기
train_data = train_datagen.flow_from_directory(
    train_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode="categorical"
)

val_data = val_datagen.flow_from_directory(
    val_dir, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode="categorical"
)
# Out:
# Found 991 images belonging to 4 classes.
# Found 99 images belonging to 4 classes.

# %%
from tensorflow.keras.applications import EfficientNetV2S
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout

# EfficientNetV2 모델 불러오기 (Pretrained weights 사용)
base_model = EfficientNetV2S(weights="imagenet", include_top=False, input_shape=(256, 256, 3))

# 기존 가중치 동결 (전이 학습)
base_model.trainable = False

# 분류기 추가
x = GlobalAveragePooling2D()(base_model.output)
x = Dense(512, activation="relu")(x)  # 더 큰 히든 레이어 추가
x = Dropout(0.4)(x)  # Dropout 증가
x = Dense(256, activation="relu")(x)
x = Dropout(0.3)(x)
x = Dense(len(classes), activation="softmax")(x)  # 클래스 개수만큼 출력 노드 설정

# 모델 생성
model = Model(inputs=base_model.input, outputs=x)

# 모델 컴파일
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# 모델 요약 출력
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-s_notop.h5
# 82420632/82420632 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 256, 256, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rescaling (Rescaling)     │ (None, 256, 256, 3)    │              0 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_conv (Conv2D)        │ (None, 128, 128, 24)   │            648 │ rescaling[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_bn                   │ (None, 128, 128, 24)   │             96 │ stem_conv[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stem_activation           │ (None, 128, 128, 24)   │              0 │ stem_bn[0][0]          │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_project_conv      │ (None, 128, 128, 24)   │          5,184 │ stem_activation[0][0]  │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_project_bn        │ (None, 128, 128, 24)   │             96 │ block1a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_project_activati… │ (None, 128, 128, 24)   │              0 │ block1a_project_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1a_add (Add)         │ (None, 128, 128, 24)   │              0 │ block1a_project_activ… │
# │                           │                        │                │ stem_activation[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_project_conv      │ (None, 128, 128, 24)   │          5,184 │ block1a_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_project_bn        │ (None, 128, 128, 24)   │             96 │ block1b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_project_activati… │ (None, 128, 128, 24)   │              0 │ block1b_project_bn[0]… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_drop (Dropout)    │ (None, 128, 128, 24)   │              0 │ block1b_project_activ… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block1b_add (Add)         │ (None, 128, 128, 24)   │              0 │ block1b_drop[0][0],    │
# │                           │                        │                │ block1a_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_expand_conv       │ (None, 64, 64, 96)     │         20,736 │ block1b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_expand_bn         │ (None, 64, 64, 96)     │            384 │ block2a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_expand_activation │ (None, 64, 64, 96)     │              0 │ block2a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_project_conv      │ (None, 64, 64, 48)     │          4,608 │ block2a_expand_activa… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2a_project_bn        │ (None, 64, 64, 48)     │            192 │ block2a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_expand_conv       │ (None, 64, 64, 192)    │         82,944 │ block2a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_expand_bn         │ (None, 64, 64, 192)    │            768 │ block2b_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_expand_activation │ (None, 64, 64, 192)    │              0 │ block2b_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_project_conv      │ (None, 64, 64, 48)     │          9,216 │ block2b_expand_activa… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_project_bn        │ (None, 64, 64, 48)     │            192 │ block2b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_drop (Dropout)    │ (None, 64, 64, 48)     │              0 │ block2b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2b_add (Add)         │ (None, 64, 64, 48)     │              0 │ block2b_drop[0][0],    │
# │                           │                        │                │ block2a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_expand_conv       │ (None, 64, 64, 192)    │         82,944 │ block2b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_expand_bn         │ (None, 64, 64, 192)    │            768 │ block2c_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_expand_activation │ (None, 64, 64, 192)    │              0 │ block2c_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_project_conv      │ (None, 64, 64, 48)     │          9,216 │ block2c_expand_activa… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_project_bn        │ (None, 64, 64, 48)     │            192 │ block2c_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_drop (Dropout)    │ (None, 64, 64, 48)     │              0 │ block2c_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2c_add (Add)         │ (None, 64, 64, 48)     │              0 │ block2c_drop[0][0],    │
# │                           │                        │                │ block2b_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_expand_conv       │ (None, 64, 64, 192)    │         82,944 │ block2c_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_expand_bn         │ (None, 64, 64, 192)    │            768 │ block2d_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_expand_activation │ (None, 64, 64, 192)    │              0 │ block2d_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_project_conv      │ (None, 64, 64, 48)     │          9,216 │ block2d_expand_activa… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_project_bn        │ (None, 64, 64, 48)     │            192 │ block2d_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_drop (Dropout)    │ (None, 64, 64, 48)     │              0 │ block2d_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block2d_add (Add)         │ (None, 64, 64, 48)     │              0 │ block2d_drop[0][0],    │
# │                           │                        │                │ block2c_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_expand_conv       │ (None, 32, 32, 192)    │         82,944 │ block2d_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_expand_bn         │ (None, 32, 32, 192)    │            768 │ block3a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_expand_activation │ (None, 32, 32, 192)    │              0 │ block3a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_project_conv      │ (None, 32, 32, 64)     │         12,288 │ block3a_expand_activa… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3a_project_bn        │ (None, 32, 32, 64)     │            256 │ block3a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_expand_conv       │ (None, 32, 32, 256)    │        147,456 │ block3a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_expand_bn         │ (None, 32, 32, 256)    │          1,024 │ block3b_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_expand_activation │ (None, 32, 32, 256)    │              0 │ block3b_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_project_conv      │ (None, 32, 32, 64)     │         16,384 │ block3b_expand_activa… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_project_bn        │ (None, 32, 32, 64)     │            256 │ block3b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_drop (Dropout)    │ (None, 32, 32, 64)     │              0 │ block3b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3b_add (Add)         │ (None, 32, 32, 64)     │              0 │ block3b_drop[0][0],    │
# │                           │                        │                │ block3a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_expand_conv       │ (None, 32, 32, 256)    │        147,456 │ block3b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_expand_bn         │ (None, 32, 32, 256)    │          1,024 │ block3c_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_expand_activation │ (None, 32, 32, 256)    │              0 │ block3c_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_project_conv      │ (None, 32, 32, 64)     │         16,384 │ block3c_expand_activa… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_project_bn        │ (None, 32, 32, 64)     │            256 │ block3c_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_drop (Dropout)    │ (None, 32, 32, 64)     │              0 │ block3c_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3c_add (Add)         │ (None, 32, 32, 64)     │              0 │ block3c_drop[0][0],    │
# │                           │                        │                │ block3b_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_expand_conv       │ (None, 32, 32, 256)    │        147,456 │ block3c_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_expand_bn         │ (None, 32, 32, 256)    │          1,024 │ block3d_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_expand_activation │ (None, 32, 32, 256)    │              0 │ block3d_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_project_conv      │ (None, 32, 32, 64)     │         16,384 │ block3d_expand_activa… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_project_bn        │ (None, 32, 32, 64)     │            256 │ block3d_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_drop (Dropout)    │ (None, 32, 32, 64)     │              0 │ block3d_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block3d_add (Add)         │ (None, 32, 32, 64)     │              0 │ block3d_drop[0][0],    │
# │                           │                        │                │ block3c_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_expand_conv       │ (None, 32, 32, 256)    │         16,384 │ block3d_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_expand_bn         │ (None, 32, 32, 256)    │          1,024 │ block4a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_expand_activation │ (None, 32, 32, 256)    │              0 │ block4a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_dwconv2           │ (None, 16, 16, 256)    │          2,304 │ block4a_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_bn                │ (None, 16, 16, 256)    │          1,024 │ block4a_dwconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_activation        │ (None, 16, 16, 256)    │              0 │ block4a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_squeeze        │ (None, 256)            │              0 │ block4a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_reshape        │ (None, 1, 1, 256)      │              0 │ block4a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_reduce         │ (None, 1, 1, 16)       │          4,112 │ block4a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_expand         │ (None, 1, 1, 256)      │          4,352 │ block4a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_se_excite         │ (None, 16, 16, 256)    │              0 │ block4a_activation[0]… │
# │ (Multiply)                │                        │                │ block4a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_project_conv      │ (None, 16, 16, 128)    │         32,768 │ block4a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4a_project_bn        │ (None, 16, 16, 128)    │            512 │ block4a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_expand_conv       │ (None, 16, 16, 512)    │         65,536 │ block4a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_expand_bn         │ (None, 16, 16, 512)    │          2,048 │ block4b_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_expand_activation │ (None, 16, 16, 512)    │              0 │ block4b_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_dwconv2           │ (None, 16, 16, 512)    │          4,608 │ block4b_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_bn                │ (None, 16, 16, 512)    │          2,048 │ block4b_dwconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_activation        │ (None, 16, 16, 512)    │              0 │ block4b_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_squeeze        │ (None, 512)            │              0 │ block4b_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_reshape        │ (None, 1, 1, 512)      │              0 │ block4b_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_reduce         │ (None, 1, 1, 32)       │         16,416 │ block4b_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_expand         │ (None, 1, 1, 512)      │         16,896 │ block4b_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_se_excite         │ (None, 16, 16, 512)    │              0 │ block4b_activation[0]… │
# │ (Multiply)                │                        │                │ block4b_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_project_conv      │ (None, 16, 16, 128)    │         65,536 │ block4b_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_project_bn        │ (None, 16, 16, 128)    │            512 │ block4b_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_drop (Dropout)    │ (None, 16, 16, 128)    │              0 │ block4b_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4b_add (Add)         │ (None, 16, 16, 128)    │              0 │ block4b_drop[0][0],    │
# │                           │                        │                │ block4a_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_expand_conv       │ (None, 16, 16, 512)    │         65,536 │ block4b_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_expand_bn         │ (None, 16, 16, 512)    │          2,048 │ block4c_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_expand_activation │ (None, 16, 16, 512)    │              0 │ block4c_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_dwconv2           │ (None, 16, 16, 512)    │          4,608 │ block4c_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_bn                │ (None, 16, 16, 512)    │          2,048 │ block4c_dwconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_activation        │ (None, 16, 16, 512)    │              0 │ block4c_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_squeeze        │ (None, 512)            │              0 │ block4c_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_reshape        │ (None, 1, 1, 512)      │              0 │ block4c_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_reduce         │ (None, 1, 1, 32)       │         16,416 │ block4c_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_expand         │ (None, 1, 1, 512)      │         16,896 │ block4c_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_se_excite         │ (None, 16, 16, 512)    │              0 │ block4c_activation[0]… │
# │ (Multiply)                │                        │                │ block4c_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_project_conv      │ (None, 16, 16, 128)    │         65,536 │ block4c_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_project_bn        │ (None, 16, 16, 128)    │            512 │ block4c_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_drop (Dropout)    │ (None, 16, 16, 128)    │              0 │ block4c_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4c_add (Add)         │ (None, 16, 16, 128)    │              0 │ block4c_drop[0][0],    │
# │                           │                        │                │ block4b_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_expand_conv       │ (None, 16, 16, 512)    │         65,536 │ block4c_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_expand_bn         │ (None, 16, 16, 512)    │          2,048 │ block4d_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_expand_activation │ (None, 16, 16, 512)    │              0 │ block4d_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_dwconv2           │ (None, 16, 16, 512)    │          4,608 │ block4d_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_bn                │ (None, 16, 16, 512)    │          2,048 │ block4d_dwconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_activation        │ (None, 16, 16, 512)    │              0 │ block4d_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_se_squeeze        │ (None, 512)            │              0 │ block4d_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_se_reshape        │ (None, 1, 1, 512)      │              0 │ block4d_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_se_reduce         │ (None, 1, 1, 32)       │         16,416 │ block4d_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_se_expand         │ (None, 1, 1, 512)      │         16,896 │ block4d_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_se_excite         │ (None, 16, 16, 512)    │              0 │ block4d_activation[0]… │
# │ (Multiply)                │                        │                │ block4d_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_project_conv      │ (None, 16, 16, 128)    │         65,536 │ block4d_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_project_bn        │ (None, 16, 16, 128)    │            512 │ block4d_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_drop (Dropout)    │ (None, 16, 16, 128)    │              0 │ block4d_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4d_add (Add)         │ (None, 16, 16, 128)    │              0 │ block4d_drop[0][0],    │
# │                           │                        │                │ block4c_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_expand_conv       │ (None, 16, 16, 512)    │         65,536 │ block4d_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_expand_bn         │ (None, 16, 16, 512)    │          2,048 │ block4e_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_expand_activation │ (None, 16, 16, 512)    │              0 │ block4e_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_dwconv2           │ (None, 16, 16, 512)    │          4,608 │ block4e_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_bn                │ (None, 16, 16, 512)    │          2,048 │ block4e_dwconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_activation        │ (None, 16, 16, 512)    │              0 │ block4e_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_se_squeeze        │ (None, 512)            │              0 │ block4e_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_se_reshape        │ (None, 1, 1, 512)      │              0 │ block4e_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_se_reduce         │ (None, 1, 1, 32)       │         16,416 │ block4e_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_se_expand         │ (None, 1, 1, 512)      │         16,896 │ block4e_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_se_excite         │ (None, 16, 16, 512)    │              0 │ block4e_activation[0]… │
# │ (Multiply)                │                        │                │ block4e_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_project_conv      │ (None, 16, 16, 128)    │         65,536 │ block4e_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_project_bn        │ (None, 16, 16, 128)    │            512 │ block4e_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_drop (Dropout)    │ (None, 16, 16, 128)    │              0 │ block4e_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4e_add (Add)         │ (None, 16, 16, 128)    │              0 │ block4e_drop[0][0],    │
# │                           │                        │                │ block4d_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_expand_conv       │ (None, 16, 16, 512)    │         65,536 │ block4e_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_expand_bn         │ (None, 16, 16, 512)    │          2,048 │ block4f_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_expand_activation │ (None, 16, 16, 512)    │              0 │ block4f_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_dwconv2           │ (None, 16, 16, 512)    │          4,608 │ block4f_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_bn                │ (None, 16, 16, 512)    │          2,048 │ block4f_dwconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_activation        │ (None, 16, 16, 512)    │              0 │ block4f_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_se_squeeze        │ (None, 512)            │              0 │ block4f_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_se_reshape        │ (None, 1, 1, 512)      │              0 │ block4f_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_se_reduce         │ (None, 1, 1, 32)       │         16,416 │ block4f_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_se_expand         │ (None, 1, 1, 512)      │         16,896 │ block4f_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_se_excite         │ (None, 16, 16, 512)    │              0 │ block4f_activation[0]… │
# │ (Multiply)                │                        │                │ block4f_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_project_conv      │ (None, 16, 16, 128)    │         65,536 │ block4f_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_project_bn        │ (None, 16, 16, 128)    │            512 │ block4f_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_drop (Dropout)    │ (None, 16, 16, 128)    │              0 │ block4f_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block4f_add (Add)         │ (None, 16, 16, 128)    │              0 │ block4f_drop[0][0],    │
# │                           │                        │                │ block4e_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_expand_conv       │ (None, 16, 16, 768)    │         98,304 │ block4f_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_expand_bn         │ (None, 16, 16, 768)    │          3,072 │ block5a_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_expand_activation │ (None, 16, 16, 768)    │              0 │ block5a_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_dwconv2           │ (None, 16, 16, 768)    │          6,912 │ block5a_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_bn                │ (None, 16, 16, 768)    │          3,072 │ block5a_dwconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_activation        │ (None, 16, 16, 768)    │              0 │ block5a_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_se_squeeze        │ (None, 768)            │              0 │ block5a_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_se_reshape        │ (None, 1, 1, 768)      │              0 │ block5a_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_se_reduce         │ (None, 1, 1, 32)       │         24,608 │ block5a_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_se_expand         │ (None, 1, 1, 768)      │         25,344 │ block5a_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_se_excite         │ (None, 16, 16, 768)    │              0 │ block5a_activation[0]… │
# │ (Multiply)                │                        │                │ block5a_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_project_conv      │ (None, 16, 16, 160)    │        122,880 │ block5a_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5a_project_bn        │ (None, 16, 16, 160)    │            640 │ block5a_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block5b_expand_conv       │ (None, 16, 16, 960)    │        153,600 │ block5a_project_bn[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# ...
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6l_project_bn        │ (None, 8, 8, 256)      │          1,024 │ block6l_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6l_drop (Dropout)    │ (None, 8, 8, 256)      │              0 │ block6l_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6l_add (Add)         │ (None, 8, 8, 256)      │              0 │ block6l_drop[0][0],    │
# │                           │                        │                │ block6k_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_expand_conv       │ (None, 8, 8, 1536)     │        393,216 │ block6l_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_expand_bn         │ (None, 8, 8, 1536)     │          6,144 │ block6m_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_expand_activation │ (None, 8, 8, 1536)     │              0 │ block6m_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_dwconv2           │ (None, 8, 8, 1536)     │         13,824 │ block6m_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_bn                │ (None, 8, 8, 1536)     │          6,144 │ block6m_dwconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_activation        │ (None, 8, 8, 1536)     │              0 │ block6m_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_se_squeeze        │ (None, 1536)           │              0 │ block6m_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_se_reshape        │ (None, 1, 1, 1536)     │              0 │ block6m_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_se_reduce         │ (None, 1, 1, 64)       │         98,368 │ block6m_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_se_expand         │ (None, 1, 1, 1536)     │         99,840 │ block6m_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_se_excite         │ (None, 8, 8, 1536)     │              0 │ block6m_activation[0]… │
# │ (Multiply)                │                        │                │ block6m_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_project_conv      │ (None, 8, 8, 256)      │        393,216 │ block6m_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_project_bn        │ (None, 8, 8, 256)      │          1,024 │ block6m_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_drop (Dropout)    │ (None, 8, 8, 256)      │              0 │ block6m_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6m_add (Add)         │ (None, 8, 8, 256)      │              0 │ block6m_drop[0][0],    │
# │                           │                        │                │ block6l_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_expand_conv       │ (None, 8, 8, 1536)     │        393,216 │ block6m_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_expand_bn         │ (None, 8, 8, 1536)     │          6,144 │ block6n_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_expand_activation │ (None, 8, 8, 1536)     │              0 │ block6n_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_dwconv2           │ (None, 8, 8, 1536)     │         13,824 │ block6n_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_bn                │ (None, 8, 8, 1536)     │          6,144 │ block6n_dwconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_activation        │ (None, 8, 8, 1536)     │              0 │ block6n_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_se_squeeze        │ (None, 1536)           │              0 │ block6n_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_se_reshape        │ (None, 1, 1, 1536)     │              0 │ block6n_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_se_reduce         │ (None, 1, 1, 64)       │         98,368 │ block6n_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_se_expand         │ (None, 1, 1, 1536)     │         99,840 │ block6n_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_se_excite         │ (None, 8, 8, 1536)     │              0 │ block6n_activation[0]… │
# │ (Multiply)                │                        │                │ block6n_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_project_conv      │ (None, 8, 8, 256)      │        393,216 │ block6n_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_project_bn        │ (None, 8, 8, 256)      │          1,024 │ block6n_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_drop (Dropout)    │ (None, 8, 8, 256)      │              0 │ block6n_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6n_add (Add)         │ (None, 8, 8, 256)      │              0 │ block6n_drop[0][0],    │
# │                           │                        │                │ block6m_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_expand_conv       │ (None, 8, 8, 1536)     │        393,216 │ block6n_add[0][0]      │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_expand_bn         │ (None, 8, 8, 1536)     │          6,144 │ block6o_expand_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_expand_activation │ (None, 8, 8, 1536)     │              0 │ block6o_expand_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_dwconv2           │ (None, 8, 8, 1536)     │         13,824 │ block6o_expand_activa… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_bn                │ (None, 8, 8, 1536)     │          6,144 │ block6o_dwconv2[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_activation        │ (None, 8, 8, 1536)     │              0 │ block6o_bn[0][0]       │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_se_squeeze        │ (None, 1536)           │              0 │ block6o_activation[0]… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_se_reshape        │ (None, 1, 1, 1536)     │              0 │ block6o_se_squeeze[0]… │
# │ (Reshape)                 │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_se_reduce         │ (None, 1, 1, 64)       │         98,368 │ block6o_se_reshape[0]… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_se_expand         │ (None, 1, 1, 1536)     │         99,840 │ block6o_se_reduce[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_se_excite         │ (None, 8, 8, 1536)     │              0 │ block6o_activation[0]… │
# │ (Multiply)                │                        │                │ block6o_se_expand[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_project_conv      │ (None, 8, 8, 256)      │        393,216 │ block6o_se_excite[0][… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_project_bn        │ (None, 8, 8, 256)      │          1,024 │ block6o_project_conv[… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_drop (Dropout)    │ (None, 8, 8, 256)      │              0 │ block6o_project_bn[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block6o_add (Add)         │ (None, 8, 8, 256)      │              0 │ block6o_drop[0][0],    │
# │                           │                        │                │ block6n_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ top_conv (Conv2D)         │ (None, 8, 8, 1280)     │        327,680 │ block6o_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ top_bn                    │ (None, 8, 8, 1280)     │          5,120 │ top_conv[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ top_activation            │ (None, 8, 8, 1280)     │              0 │ top_bn[0][0]           │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 1280)           │              0 │ top_activation[0][0]   │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 512)            │        655,872 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 512)            │              0 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 256)            │        131,328 │ dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (None, 256)            │              0 │ dense_1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 4)              │          1,028 │ dropout_1[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 21,119,588 (80.56 MB)
#  Trainable params: 788,228 (3.01 MB)
#  Non-trainable params: 20,331,360 (77.56 MB)

# %%
# 모델 학습 설정
mongo_logger = MongoLoggingCallback()

EPOCHS = 20

history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=EPOCHS,
    verbose=1,
    callbacks=[mongo_logger]
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5282 - loss: 1.0926📤 MongoDB에 Epoch 1 로그 저장됨
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.5298 - loss: 1.0897 - val_accuracy: 0.6566 - val_loss: 0.7103
# Epoch 2/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.6193 - loss: 0.8883📤 MongoDB에 Epoch 2 로그 저장됨
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 17s 535ms/step - accuracy: 0.6196 - loss: 0.8881 - val_accuracy: 0.7374 - val_loss: 0.6790
# Epoch 3/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - accuracy: 0.6636 - loss: 0.7954📤 MongoDB에 Epoch 3 로그 저장됨
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 17s 533ms/step - accuracy: 0.6634 - loss: 0.7957 - val_accuracy: 0.7980 - val_loss: 0.6559
# Epoch 4/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - accuracy: 0.6890 - loss: 0.7764📤 MongoDB에 Epoch 4 로그 저장됨
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 17s 533ms/step - accuracy: 0.6893 - loss: 0.7763 - val_accuracy: 0.7879 - val_loss: 0.6488
# Epoch 5/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.6959 - loss: 0.7470📤 MongoDB에 Epoch 5 로그 저장됨
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 17s 535ms/step - accuracy: 0.6953 - loss: 0.7479 - val_accuracy: 0.7475 - val_loss: 0.7193
# Epoch 6/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - accuracy: 0.6835 - loss: 0.7624📤 MongoDB에 Epoch 6 로그 저장됨
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 17s 538ms/step - accuracy: 0.6838 - loss: 0.7619 - val_accuracy: 0.8283 - val_loss: 0.6186
# Epoch 7/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - accuracy: 0.7016 - loss: 0.7403📤 MongoDB에 Epoch 7 로그 저장됨
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 17s 538ms/step - accuracy: 0.7020 - loss: 0.7395 - val_accuracy: 0.7475 - val_loss: 0.6982
# Epoch 8/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - accuracy: 0.6997 - loss: 0.7256📤 MongoDB에 Epoch 8 로그 저장됨
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 17s 534ms/step - accuracy: 0.6997 - loss: 0.7255 - val_accuracy: 0.8283 - val_loss: 0.5560
# Epoch 9/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - accuracy: 0.7325 - loss: 0.6409📤 MongoDB에 Epoch 9 로그 저장됨
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 17s 538ms/step - accuracy: 0.7324 - loss: 0.6411 - val_accuracy: 0.7576 - val_loss: 0.7142
# Epoch 10/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - accuracy: 0.7343 - loss: 0.6826📤 MongoDB에 Epoch 10 로그 저장됨
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 17s 537ms/step - accuracy: 0.7338 - loss: 0.6826 - val_accuracy: 0.7980 - val_loss: 0.6822
# Epoch 11/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 512ms/step - accuracy: 0.7190 - loss: 0.6852📤 MongoDB에 Epoch 11 로그 저장됨
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 17s 532ms/step - accuracy: 0.7191 - loss: 0.6851 - val_accuracy: 0.7677 - val_loss: 0.6140
# Epoch 12/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - accuracy: 0.7068 - loss: 0.6762📤 MongoDB에 Epoch 12 로그 저장됨
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 17s 540ms/step - accuracy: 0.7072 - loss: 0.6755 - val_accuracy: 0.7273 - val_loss: 0.5920
# Epoch 13/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - accuracy: 0.7024 - loss: 0.6749📤 MongoDB에 Epoch 13 로그 저장됨
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 17s 540ms/step - accuracy: 0.7030 - loss: 0.6742 - val_accuracy: 0.7980 - val_loss: 0.5959
# Epoch 14/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - accuracy: 0.7629 - loss: 0.6150📤 MongoDB에 Epoch 14 로그 저장됨
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 17s 533ms/step - accuracy: 0.7626 - loss: 0.6152 - val_accuracy: 0.7071 - val_loss: 0.6780
# Epoch 15/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - accuracy: 0.7371 - loss: 0.6662📤 MongoDB에 Epoch 15 로그 저장됨
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 17s 536ms/step - accuracy: 0.7371 - loss: 0.6661 - val_accuracy: 0.7778 - val_loss: 0.6261
# Epoch 16/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.7085 - loss: 0.6848📤 MongoDB에 Epoch 16 로그 저장됨
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 17s 536ms/step - accuracy: 0.7087 - loss: 0.6848 - val_accuracy: 0.6566 - val_loss: 0.8248
# Epoch 17/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - accuracy: 0.7323 - loss: 0.6536📤 MongoDB에 Epoch 17 로그 저장됨
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 17s 550ms/step - accuracy: 0.7321 - loss: 0.6545 - val_accuracy: 0.7879 - val_loss: 0.6694
# Epoch 18/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - accuracy: 0.7344 - loss: 0.6518📤 MongoDB에 Epoch 18 로그 저장됨
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 17s 537ms/step - accuracy: 0.7343 - loss: 0.6520 - val_accuracy: 0.8081 - val_loss: 0.5485
# Epoch 19/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - accuracy: 0.7635 - loss: 0.6096📤 MongoDB에 Epoch 19 로그 저장됨
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 17s 534ms/step - accuracy: 0.7635 - loss: 0.6098 - val_accuracy: 0.8283 - val_loss: 0.4788
# Epoch 20/20
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - accuracy: 0.7503 - loss: 0.6038📤 MongoDB에 Epoch 20 로그 저장됨
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 17s 534ms/step - accuracy: 0.7500 - loss: 0.6045 - val_accuracy: 0.7273 - val_loss: 0.7400

# %%
# 일부 레이어를 학습 가능하도록 설정
base_model.trainable = True

# 모델 재컴파일 (학습률 낮춤)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5), loss="categorical_crossentropy", metrics=["accuracy"])

# 추가 학습
EPOCHS_FINE_TUNE = 8

history_finetune = model.fit(
    train_data,
    validation_data=val_data,
    epochs=EPOCHS_FINE_TUNE,
    verbose=1,
    callbacks=[mongo_logger]
)
# Out:
# Epoch 1/8
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4140 - loss: 3.6495📤 MongoDB에 Epoch 1 로그 저장됨
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 252s 3s/step - accuracy: 0.4176 - loss: 3.6124 - val_accuracy: 0.3535 - val_loss: 2.2176
# Epoch 2/8
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.6778 - loss: 0.8655📤 MongoDB에 Epoch 2 로그 저장됨
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 17s 534ms/step - accuracy: 0.6786 - loss: 0.8643 - val_accuracy: 0.5455 - val_loss: 1.4763
# Epoch 3/8
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - accuracy: 0.7595 - loss: 0.5569📤 MongoDB에 Epoch 3 로그 저장됨
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 17s 539ms/step - accuracy: 0.7595 - loss: 0.5565 - val_accuracy: 0.7374 - val_loss: 0.4636
# Epoch 4/8
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - accuracy: 0.7975 - loss: 0.4001📤 MongoDB에 Epoch 4 로그 저장됨
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 17s 534ms/step - accuracy: 0.7975 - loss: 0.4009 - val_accuracy: 0.7475 - val_loss: 0.3378
# Epoch 5/8
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 523ms/step - accuracy: 0.8232 - loss: 0.4192📤 MongoDB에 Epoch 5 로그 저장됨
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 17s 543ms/step - accuracy: 0.8232 - loss: 0.4179 - val_accuracy: 0.7677 - val_loss: 0.3126
# Epoch 6/8
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - accuracy: 0.8149 - loss: 0.3945📤 MongoDB에 Epoch 6 로그 저장됨
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 17s 538ms/step - accuracy: 0.8153 - loss: 0.3931 - val_accuracy: 0.7879 - val_loss: 0.3054
# Epoch 7/8
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - accuracy: 0.8189 - loss: 0.3605📤 MongoDB에 Epoch 7 로그 저장됨
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 17s 537ms/step - accuracy: 0.8195 - loss: 0.3600 - val_accuracy: 0.8182 - val_loss: 0.2916
# Epoch 8/8
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - accuracy: 0.8327 - loss: 0.3628📤 MongoDB에 Epoch 8 로그 저장됨
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 17s 540ms/step - accuracy: 0.8331 - loss: 0.3610 - val_accuracy: 0.8384 - val_loss: 0.2808

# %%
import matplotlib.pyplot as plt

# 학습 결과 시각화
plt.figure(figsize=(12, 4))

# Loss 그래프
plt.subplot(1, 2, 1)
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.plot(history_finetune.history["loss"], label="Fine-Tune Train Loss", linestyle="dashed")
plt.plot(history_finetune.history["val_loss"], label="Fine-Tune Validation Loss", linestyle="dashed")
plt.legend()
plt.title("Loss Curve")

# Accuracy 그래프
plt.subplot(1, 2, 2)
plt.plot(history.history["accuracy"], label="Train Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
plt.plot(history_finetune.history["accuracy"], label="Fine-Tune Train Accuracy", linestyle="dashed")
plt.plot(history_finetune.history["val_accuracy"], label="Fine-Tune Validation Accuracy", linestyle="dashed")
plt.legend()
plt.title("Accuracy Curve")

plt.show()

# %%
# 검증 데이터 평가
val_loss, val_acc = model.evaluate(val_data)
print(f"✅ Validation Accuracy: {val_acc:.4f}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.8479 - loss: 0.2600
# ✅ Validation Accuracy: 0.8384

# %%
model.save("/content/drive/MyDrive/colab/orange_disease_model.keras")
print("✅ 모델이 .keras 형식으로 저장되었습니다.")
# Out:
# ✅ 모델이 .keras 형식으로 저장되었습니다.

# %%
from tensorflow import keras

model = keras.models.load_model("/content/drive/MyDrive/colab/orange_disease_model.keras")
print("✅ .keras 모델이 성공적으로 로드되었습니다.")

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

# 예측 함수 정의
def predict_image(img_path):
    # 이미지 로드 및 전처리
    img = image.load_img(img_path, target_size=IMG_SIZE)
    img_array = image.img_to_array(img)
    img_array = img_array / 255.0  # 정규화
    img_array = np.expand_dims(img_array, axis=0)  # 배치 차원 추가

    # 예측
    predictions = model.predict(img_array)
    predicted_class = np.argmax(predictions[0])
    class_name = classes[predicted_class]

    # 결과 출력
    print(f"🟠 예측된 클래스: {class_name}")
    plt.imshow(img)
    plt.title(f"Predicted: {class_name}")
    plt.axis("off")
    plt.show()

# 클래스분류 예측 테스트
test_image_path = "/content/drive/MyDrive/colab/check/rtest_1.jpg"
predict_image(test_image_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step
# 🟠 예측된 클래스: blackspot

# %%
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
import os

# 예측 함수 정의
def predict_multiple_images(img_paths):
    plt.figure(figsize=(20, 10))

    for i, img_path in enumerate(img_paths):
        if not os.path.exists(img_path):
            print(f"⚠️ 파일 없음: {img_path}")
            continue

        # 이미지 로드 및 전처리
        img = image.load_img(img_path, target_size=IMG_SIZE)
        img_array = image.img_to_array(img)
        img_array = img_array / 255.0
        img_array = np.expand_dims(img_array, axis=0)

        # 예측
        predictions = model.predict(img_array)
        predicted_class = np.argmax(predictions[0])
        class_name = classes[predicted_class]

        # 결과 출력 (서브플롯)
        plt.subplot(3, 4, i + 1)
        plt.imshow(img)
        plt.title(f"{os.path.basename(img_path)}\nPredicted: {class_name}", fontsize=10)
        plt.axis("off")

    plt.tight_layout()
    plt.show()

# 이미지 경로 리스트
test_image_paths = [f"/content/drive/MyDrive/colab/check/rtest_{i}.jpg" for i in range(1, 12)]

# 예측 실행
predict_multiple_images(test_image_paths)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
